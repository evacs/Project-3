# %%
#adding dependedncies
import pandas as pd
import numpy as np

# %%
#importing data
crime_data_df = pd.read_csv('../resources/fbi_hate_crime_data.csv')
crime_data_df.head()
# Out:
#    incident_id  data_year        ori    pug_agency_name pub_agency_unit  \
# 0           43       1991  AR0350100         Pine Bluff             NaN
# 1           44       1991  AR0350100         Pine Bluff             NaN
# 2           45       1991  AR0600300  North Little Rock             NaN
# 3           46       1991  AR0600300  North Little Rock             NaN
# 4           47       1991  AR0670000             Sevier             NaN
#
#   agency_type_name state_abbr state_name       division_name region_name  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4           County         AR   Arkansas  West South Central       South  ...
#
#                offender_race offender_ethnicity victim_count  \
# 0  Black or African American      Not Specified            1
# 1  Black or African American      Not Specified            2
# 2  Black or African American      Not Specified            2
# 3  Black or African American      Not Specified            1
# 4                      White      Not Specified            1
#
#                                         offense_name  \
# 0                                 Aggravated Assault
# 1  Aggravated Assault;Destruction/Damage/Vandalis...
# 2  Aggravated Assault;Murder and Nonnegligent Man...
# 3                                       Intimidation
# 4                                       Intimidation
#
#    total_individual_victims                       location_name  \
# 0                       1.0                      Residence/Home
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       2.0                      Residence/Home
# 3                       1.0                      Residence/Home
# 4                       1.0                      School/College
#
#                         bias_desc  victim_types multiple_offense multiple_bias
# 0  Anti-Black or African American    Individual                S             S
# 1                      Anti-White    Individual                M             S
# 2                      Anti-White    Individual                M             S
# 3                      Anti-White    Individual                S             S
# 4  Anti-Black or African American    Individual                S             S
#
# [5 rows x 28 columns]

# %%
#removing unneeded columns
crime_data_df = crime_data_df[['incident_id', 'data_year', 'pug_agency_name', 'state_abbr', 
                               'state_name', 'division_name', 'region_name', 'offender_race', 
                               'offender_ethnicity', 'victim_count', 'offense_name', 'total_individual_victims',
                              'location_name', 'bias_desc', 'victim_types', 'multiple_offense', 'multiple_bias']]
crime_data_df.head()
# Out:
#    incident_id  data_year    pug_agency_name state_abbr state_name  \
# 0           43       1991         Pine Bluff         AR   Arkansas
# 1           44       1991         Pine Bluff         AR   Arkansas
# 2           45       1991  North Little Rock         AR   Arkansas
# 3           46       1991  North Little Rock         AR   Arkansas
# 4           47       1991             Sevier         AR   Arkansas
#
#         division_name region_name              offender_race  \
# 0  West South Central       South  Black or African American
# 1  West South Central       South  Black or African American
# 2  West South Central       South  Black or African American
# 3  West South Central       South  Black or African American
# 4  West South Central       South                      White
#
#   offender_ethnicity  victim_count  \
# 0      Not Specified             1
# 1      Not Specified             2
# 2      Not Specified             2
# 3      Not Specified             1
# 4      Not Specified             1
#
#                                         offense_name  \
# 0                                 Aggravated Assault
# 1  Aggravated Assault;Destruction/Damage/Vandalis...
# 2  Aggravated Assault;Murder and Nonnegligent Man...
# 3                                       Intimidation
# 4                                       Intimidation
#
#    total_individual_victims                       location_name  \
# 0                       1.0                      Residence/Home
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       2.0                      Residence/Home
# 3                       1.0                      Residence/Home
# 4                       1.0                      School/College
#
#                         bias_desc victim_types multiple_offense multiple_bias
# 0  Anti-Black or African American   Individual                S             S
# 1                      Anti-White   Individual                M             S
# 2                      Anti-White   Individual                M             S
# 3                      Anti-White   Individual                S             S
# 4  Anti-Black or African American   Individual                S             S

# %%
#creating csv file for ethnicity data
ethnicity_types_df = pd.DataFrame(crime_data_df['offender_ethnicity'].unique(), columns=['ethnicity_type'])
ethnicity_types_df.index.name = 'ethnicity_type_id'

print(f"Max column size - ethnicity_type: {ethnicity_types_df['ethnicity_type'].map(lambda x: len(x)).max()}")

ethnicity_types_df
# Out:
# Max column size - ethnicity_type: 22
#                            ethnicity_type
# ethnicity_type_id
# 0                           Not Specified
# 1                                 Unknown
# 2                  Not Hispanic or Latino
# 3                      Hispanic or Latino
# 4                                Multiple

# %%
#exporting ethnicity dataframe as a csv for upload
ethnicity_types_df.to_csv('resources/ethnicity_types.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %%
#creating csv for offenses data
#splitting multiple offenses
filtered_df = crime_data_df[crime_data_df["multiple_offense"]=="M"]
filtered_df["offense_name"] =filtered_df["offense_name"].str.split(';')
explode_df = filtered_df.explode("offense_name", ignore_index=True)
explode_df.head(20)
# Out:
# C:\Users\a2pha\AppData\Local\Temp\ipykernel_2264\1621890545.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["offense_name"] =filtered_df["offense_name"].str.split(';')
#     incident_id    pug_agency_name state_abbr state_name       division_name  \
# 0            44         Pine Bluff         AR   Arkansas  West South Central
# 1            44         Pine Bluff         AR   Arkansas  West South Central
# 2            45  North Little Rock         AR   Arkansas  West South Central
# 3            45  North Little Rock         AR   Arkansas  West South Central
# 4            23            Phoenix         AZ    Arizona            Mountain
# 5            23            Phoenix         AZ    Arizona            Mountain
# 6            31            Phoenix         AZ    Arizona            Mountain
# 7            31            Phoenix         AZ    Arizona            Mountain
# 8            55             Denver         CO   Colorado            Mountain
# 9            55             Denver         CO   Colorado            Mountain
# 10           90           Arapahoe         CO   Colorado            Mountain
# 11           90           Arapahoe         CO   Colorado            Mountain
# 12          100   Colorado Springs         CO   Colorado            Mountain
# 13          100   Colorado Springs         CO   Colorado            Mountain
# 14          100   Colorado Springs         CO   Colorado            Mountain
# 15          112           Trinidad         CO   Colorado            Mountain
# 16          112           Trinidad         CO   Colorado            Mountain
# 17          112           Trinidad         CO   Colorado            Mountain
# 18         2757             Aurora         CO   Colorado            Mountain
# 19         2757             Aurora         CO   Colorado            Mountain
#
#    region_name              offender_race offender_ethnicity  victim_count  \
# 0        South  Black or African American      Not Specified             2
# 1        South  Black or African American      Not Specified             2
# 2        South  Black or African American      Not Specified             2
# 3        South  Black or African American      Not Specified             2
# 4         West                      White      Not Specified             3
# 5         West                      White      Not Specified             3
# 6         West                      White      Not Specified             2
# 7         West                      White      Not Specified             2
# 8         West                      White      Not Specified             2
# 9         West                      White      Not Specified             2
# 10        West                      White      Not Specified             3
# 11        West                      White      Not Specified             3
# 12        West                      White      Not Specified             6
# 13        West                      White      Not Specified             6
# 14        West                      White      Not Specified             6
# 15        West                    Unknown      Not Specified             3
# 16        West                    Unknown      Not Specified             3
# 17        West                    Unknown      Not Specified             3
# 18        West  Black or African American      Not Specified             2
# 19        West  Black or African American      Not Specified             2
#
#                                 offense_name  total_individual_victims  \
# 0                         Aggravated Assault                       1.0
# 1   Destruction/Damage/Vandalism of Property                       1.0
# 2                         Aggravated Assault                       2.0
# 3       Murder and Nonnegligent Manslaughter                       2.0
# 4   Destruction/Damage/Vandalism of Property                       2.0
# 5                               Intimidation                       2.0
# 6                         Aggravated Assault                       2.0
# 7                               Intimidation                       2.0
# 8                         Aggravated Assault                       1.0
# 9                               Intimidation                       1.0
# 10                              Intimidation                       3.0
# 11                            Simple Assault                       3.0
# 12  Destruction/Damage/Vandalism of Property                       2.0
# 13                              Intimidation                       2.0
# 14                            Simple Assault                       2.0
# 15              Burglary/Breaking & Entering                       0.0
# 16  Destruction/Damage/Vandalism of Property                       0.0
# 17                             Not Specified                       0.0
# 18                        Aggravated Assault                       1.0
# 19                             Not Specified                       1.0
#
#                          location_name                       bias_desc  \
# 0   Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 1   Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 2                       Residence/Home                      Anti-White
# 3                       Residence/Home                      Anti-White
# 4   Highway/Road/Alley/Street/Sidewalk  Anti-Black or African American
# 5   Highway/Road/Alley/Street/Sidewalk  Anti-Black or African American
# 6                  Grocery/Supermarket  Anti-Black or African American
# 7                  Grocery/Supermarket  Anti-Black or African American
# 8   Highway/Road/Alley/Street/Sidewalk  Anti-Black or African American
# 9   Highway/Road/Alley/Street/Sidewalk  Anti-Black or African American
# 10                 Service/Gas Station         Anti-Hispanic or Latino
# 11                 Service/Gas Station         Anti-Hispanic or Latino
# 12             Parking/Drop Lot/Garage  Anti-Black or African American
# 13             Parking/Drop Lot/Garage  Anti-Black or African American
# 14             Parking/Drop Lot/Garage  Anti-Black or African American
# 15      Church/Synagogue/Temple/Mosque                   Anti-Catholic
# 16      Church/Synagogue/Temple/Mosque                   Anti-Catholic
# 17      Church/Synagogue/Temple/Mosque                   Anti-Catholic
# 18           Department/Discount Store                      Anti-White
# 19           Department/Discount Store                      Anti-White
#
#               victim_types multiple_offense multiple_bias
# 0               Individual                M             S
# 1               Individual                M             S
# 2               Individual                M             S
# 3               Individual                M             S
# 4               Individual                M             S
# 5               Individual                M             S
# 6               Individual                M             S
# 7               Individual                M             S
# 8               Individual                M             S
# 9               Individual                M             S
# 10              Individual                M             S
# 11              Individual                M             S
# 12              Individual                M             S
# 13              Individual                M             S
# 14              Individual                M             S
# 15  Religious Organization                M             S
# 16  Religious Organization                M             S
# 17  Religious Organization                M             S
# 18     Business;Individual                M             S
# 19     Business;Individual                M             S

# %%
#creating dataframe of offense types
offense_types_df = pd.DataFrame(explode_df['offense_name'].unique(), columns=['offense_type'])
offense_types_df.index.name = 'offense_type_id'

print(f"Max column size - offense_type: {offense_types_df['offense_type'].map(lambda x: len(x)).max()}")

offense_types_df
# Out:
# Max column size - offense_type: 43
#                                                 offense_type
# offense_type_id
# 0                                         Aggravated Assault
# 1                   Destruction/Damage/Vandalism of Property
# 2                       Murder and Nonnegligent Manslaughter
# 3                                               Intimidation
# 4                                             Simple Assault
# 5                               Burglary/Breaking & Entering
# 6                                              Not Specified
# 7                                                      Arson
# 8                                                    Robbery
# 9                                                       Rape
# 10                                       Motor Vehicle Theft
# 11                                         All Other Larceny
# 12                                     Weapon Law Violations
# 13                                  Theft From Motor Vehicle
# 14                                               Shoplifting
# 15                                      Kidnapping/Abduction
# 16               Theft of Motor Vehicle Parts or Accessories
# 17                                                    Sodomy
# 18                                  Stolen Property Offenses
# 19                                 Drug Equipment Violations
# 20                                  Drug/Narcotic Violations
# 21                                       Theft From Building
# 22                                    Counterfeiting/Forgery
# 23                                             Impersonation
# 24                                       Extortion/Blackmail
# 25                                                  Fondling
# 26                   False Pretenses/Swindle/Confidence Game
# 27                              Pornography/Obscene Material
# 28                                              Embezzlement
# 29                             Sexual Assault With An Object
# 30                Credit Card/Automated Teller Machine Fraud
# 31                                           Purse-snatching
# 32                                              Prostitution
# 33                                            Pocket-picking
# 34                                            Statutory Rape
# 35                                                   Bribery
# 36                                            Identity Theft
# 37                                                Wire Fraud
# 38                    Human Trafficking, Commercial Sex Acts
# 39                                            Animal Cruelty
# 40                                 Hacking/Computer Invasion

# %%
#exporting offenses dataframe as a csv for upload
offense_types_df.to_csv('resources/offense_types.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %%
#creating dataframe for incident id numbers
inci_df = crime_data_df[['incident_id','offense_name']]
inci_df.head()
# Out:
#    incident_id                                       offense_name
# 0           43                                 Aggravated Assault
# 1           44  Aggravated Assault;Destruction/Damage/Vandalis...
# 2           45  Aggravated Assault;Murder and Nonnegligent Man...
# 3           46                                       Intimidation
# 4           47                                       Intimidation

# %%
inci_df = inci_df.rename(columns={'offense_name' : 'offense_type'})
inci_df.head()
# Out:
#    incident_id                                       offense_type
# 0           43                                 Aggravated Assault
# 1           44  Aggravated Assault;Destruction/Damage/Vandalis...
# 2           45  Aggravated Assault;Murder and Nonnegligent Man...
# 3           46                                       Intimidation
# 4           47                                       Intimidation

# %%
incident_offense = inci_df.merge(offense_types_df,on  = "offense_type", how = 'right')
incident_offense = incident_offense[["incident_id","offense_type"]]
incident_offense.head(20)
# Out:
#     incident_id        offense_type
# 0            43  Aggravated Assault
# 1          3017  Aggravated Assault
# 2          3019  Aggravated Assault
# 3             5  Aggravated Assault
# 4            17  Aggravated Assault
# 5            18  Aggravated Assault
# 6            25  Aggravated Assault
# 7            30  Aggravated Assault
# 8            35  Aggravated Assault
# 9            38  Aggravated Assault
# 10           39  Aggravated Assault
# 11           40  Aggravated Assault
# 12           51  Aggravated Assault
# 13           58  Aggravated Assault
# 14           62  Aggravated Assault
# 15           64  Aggravated Assault
# 16           68  Aggravated Assault
# 17           77  Aggravated Assault
# 18           78  Aggravated Assault
# 19           97  Aggravated Assault
