# %% [markdown]
# # Hate Crime Data Extraction and Transformation
#
# 1. Create dataframe from FBI hate crimes spreadsheet and explore
# 2. Create dataframes for needed database tables and export to csv files

# %%
# Dependencies and Setup
import pandas as pd
import requests
from pathlib import Path

# %% [markdown]
# ## Create/Explore FBI Hate Crime Dataframe

# %%
# Path to hate crime data
path = Path('../resources/fbi_hate_crime_data.csv')

# Load hate crime data
crime_data_df = pd.read_csv(path, index_col=0)

# Display sample data
crime_data_df.head()
# Out:
#              data_year        ori    pug_agency_name pub_agency_unit  \
# incident_id
# 43                1991  AR0350100         Pine Bluff             NaN
# 44                1991  AR0350100         Pine Bluff             NaN
# 45                1991  AR0600300  North Little Rock             NaN
# 46                1991  AR0600300  North Little Rock             NaN
# 47                1991  AR0670000             Sevier             NaN
#
#             agency_type_name state_abbr state_name       division_name  \
# incident_id
# 43                      City         AR   Arkansas  West South Central
# 44                      City         AR   Arkansas  West South Central
# 45                      City         AR   Arkansas  West South Central
# 46                      City         AR   Arkansas  West South Central
# 47                    County         AR   Arkansas  West South Central
#
#             region_name population_group_code  ...              offender_race  \
# incident_id                                    ...
# 43                South                     3  ...  Black or African American
# 44                South                     3  ...  Black or African American
# 45                South                     3  ...  Black or African American
# 46                South                     3  ...  Black or African American
# 47                South                    8D  ...                      White
#
#             offender_ethnicity  victim_count  \
# incident_id
# 43               Not Specified             1
# 44               Not Specified             2
# 45               Not Specified             2
# 46               Not Specified             1
# 47               Not Specified             1
#
#                                                   offense_name  \
# incident_id
# 43                                          Aggravated Assault
# 44           Aggravated Assault;Destruction/Damage/Vandalis...
# 45           Aggravated Assault;Murder and Nonnegligent Man...
# 46                                                Intimidation
# 47                                                Intimidation
#
#              total_individual_victims                       location_name  \
# incident_id
# 43                                1.0                      Residence/Home
# 44                                1.0  Highway/Road/Alley/Street/Sidewalk
# 45                                2.0                      Residence/Home
# 46                                1.0                      Residence/Home
# 47                                1.0                      School/College
#
#                                   bias_desc victim_types multiple_offense  \
# incident_id
# 43           Anti-Black or African American   Individual                S
# 44                               Anti-White   Individual                M
# 45                               Anti-White   Individual                M
# 46                               Anti-White   Individual                S
# 47           Anti-Black or African American   Individual                S
#
#              multiple_bias
# incident_id
# 43                       S
# 44                       S
# 45                       S
# 46                       S
# 47                       S
#
# [5 rows x 27 columns]

# %%
crime_data_df = crime_data_df[crime_data_df['data_year'] > 2008]
crime_data_df.head()
# Out:
#              data_year        ori pug_agency_name pub_agency_unit  \
# incident_id
# 141003            2009  AK0010100       Anchorage             NaN
# 141004            2009  AK0010100       Anchorage             NaN
# 141005            2009  AK0010100       Anchorage             NaN
# 141006            2009  AK0010100       Anchorage             NaN
# 141007            2009  AK0010100       Anchorage             NaN
#
#             agency_type_name state_abbr state_name division_name region_name  \
# incident_id
# 141003                  City         AK     Alaska       Pacific        West
# 141004                  City         AK     Alaska       Pacific        West
# 141005                  City         AK     Alaska       Pacific        West
# 141006                  City         AK     Alaska       Pacific        West
# 141007                  City         AK     Alaska       Pacific        West
#
#             population_group_code  ... offender_race offender_ethnicity  \
# incident_id                        ...
# 141003                         1C  ...         White      Not Specified
# 141004                         1C  ...       Unknown      Not Specified
# 141005                         1C  ...         White      Not Specified
# 141006                         1C  ...      Multiple      Not Specified
# 141007                         1C  ...         Asian      Not Specified
#
#              victim_count        offense_name  total_individual_victims  \
# incident_id
# 141003                  1      Simple Assault                       1.0
# 141004                  1        Intimidation                       1.0
# 141005                  1             Robbery                       1.0
# 141006                  4  Aggravated Assault                       4.0
# 141007                  1             Robbery                       1.0
#
#                                   location_name  \
# incident_id
# 141003       Highway/Road/Alley/Street/Sidewalk
# 141004                           Residence/Home
# 141005       Highway/Road/Alley/Street/Sidewalk
# 141006       Highway/Road/Alley/Street/Sidewalk
# 141007       Highway/Road/Alley/Street/Sidewalk
#
#                                                      bias_desc victim_types  \
# incident_id
# 141003                   Anti-American Indian or Alaska Native   Individual
# 141004       Anti-Lesbian, Gay, Bisexual, or Transgender (M...   Individual
# 141005                   Anti-American Indian or Alaska Native   Individual
# 141006                   Anti-American Indian or Alaska Native   Individual
# 141007                   Anti-American Indian or Alaska Native   Individual
#
#             multiple_offense  multiple_bias
# incident_id
# 141003                     S              S
# 141004                     S              S
# 141005                     S              S
# 141006                     S              S
# 141007                     S              S
#
# [5 rows x 27 columns]

# %%
crime_data_df.dtypes
# Out:
# data_year                         int64
# ori                              object
# pug_agency_name                  object
# pub_agency_unit                  object
# agency_type_name                 object
# state_abbr                       object
# state_name                       object
# division_name                    object
# region_name                      object
# population_group_code            object
# population_group_description     object
# incident_date                    object
# adult_victim_count              float64
# juvenile_victim_count           float64
# total_offender_count              int64
# adult_offender_count            float64
# juvenile_offender_count         float64
# offender_race                    object
# offender_ethnicity               object
# victim_count                      int64
# offense_name                     object
# total_individual_victims        float64
# location_name                    object
# bias_desc                        object
# victim_types                     object
# multiple_offense                 object
# multiple_bias                    object
# dtype: object

# %% [markdown]
# ## Create CSV Files for Database Tables

# %% [markdown]
# ### Table: agency_types

# %%
# Create dataframe for agency_types and rename index
agency_types_df = pd.DataFrame(crime_data_df['agency_type_name'].unique(), columns=['agency_type'])
agency_types_df.index.name = 'agency_type_id'

# Code Reference: https://stackoverflow.com/questions/21295334/find-length-of-longest-string-in-pandas-dataframe-column
print(f"Max column size - agency_type: {agency_types_df['agency_type'].map(lambda x: len(x)).max()}")

agency_types_df
# Out:
# Max column size - agency_type: 21
#                           agency_type
# agency_type_id
# 0                                City
# 1                              County
# 2               University or College
# 3                               Other
# 4                  Other State Agency
# 5                        State Police
# 6                              Tribal
# 7                             Federal

# %%
# Export agency_types dataframe to csv 
agency_types_df.to_csv('data/agency_types.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %% [markdown]
# ### Table: states

# %%
# # Create dataframe for states
states_df = crime_data_df.loc[:, ['state_abbr', 'state_name', 'division_name', 'region_name']].groupby('state_abbr').first()
states_renamed_df = states_df.rename(columns={'state_name': 'state', 'division_name': 'division', 'region_name': 'region'})

# Print maximum size of each column for database schema
print(f"Max column size - state_name: {states_df['state_name'].map(lambda x: len(x)).max()}")
print(f"Max column size - division_name: {states_df['division_name'].map(lambda x: len(x)).max()}")
print(f"Max column size - region_name: {states_df['region_name'].map(lambda x: len(x)).max()}")

# Display sample data
states_renamed_df.head()
# Out:
# Max column size - state_name: 20
# Max column size - division_name: 18
# Max column size - region_name: 16
#                  state            division region
# state_abbr
# AK              Alaska             Pacific   West
# AL             Alabama  East South Central  South
# AR            Arkansas  West South Central  South
# AZ             Arizona            Mountain   West
# CA          California             Pacific   West

# %%
# Export states dataframe to csv 
states_renamed_df.to_csv('data/states.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %% [markdown]
# ### Table: agencies

# %%
# Create agencies csv
# Code Reference for as_index:
# https://stackoverflow.com/questions/21767900/how-to-move-pandas-data-from-index-to-column-after-multiple-groupby
agencies_df = crime_data_df.loc[:, ['pug_agency_name', 'pub_agency_unit', 'agency_type_name']].groupby('pug_agency_name', as_index=False, dropna=False).first()
agency_oris = crime_data_df.loc[:, ['ori', 'pug_agency_name', 'pub_agency_unit', 'agency_type_name']].groupby('ori', as_index=False, dropna=False).first()
agency_units = crime_data_df.loc[:, ['ori', 'pug_agency_name', 'pub_agency_unit', 'agency_type_name']].groupby(['pug_agency_name', 'pub_agency_unit'], as_index=False, dropna=False).first()
test = agency_units.sort_values(by=['ori'])

# Print maximum size of each column for database schema
print(len(agencies_df))
print(len(agency_oris))
print(len(agency_units))

# Display sample data

#test = agency_units[agency_units['agency_type_name'] == 'City'].sort_values(by='ori')
test = agency_oris[agency_oris['agency_type_name'] == 'City'].sort_values(by='ori')
print(len(test))
test.head(20)
# Out:
# 5313
# 7669
# 5780
# 5123
#           ori pug_agency_name pub_agency_unit agency_type_name
# 0   AK0010100       Anchorage            None             City
# 1   AK0010200       Fairbanks            None             City
# 2   AK0010300          Juneau            None             City
# 3   AK0010600            Nome            None             City
# 4   AK0010700      Petersburg            None             City
# 5   AK0010800          Seward            None             City
# 6   AK0011300          Bethel            None             City
# 7   AK0011600        Kotzebue            None             City
# 8   AK0011700          Palmer            None             City
# 9   AK0012000        Soldotna            None             City
# 10  AK0013200      North Pole            None             City
# 11  AK0015600         Wasilla            None             City
# 15  AL0010200      Birmingham            None             City
# 16  AL0010400       Fairfield            None             City
# 17  AL0010700        Midfield            None             City
# 18  AL0010900  Vestavia Hills            None             City
# 19  AL0011100      Fultondale            None             City
# 20  AL0011200          Hoover            None             City
# 21  AL0011300        Irondale            None             City
# 22  AL0011400  Pleasant Grove            None             City

# %%
# Export dataframe to csv 
states_df.to_csv('data/states.csv')

# Confirm that export completed
print('Dataframe exported to csv')

# %% [markdown]
# ### Table: population_groups

# %%
# Create dataframe for population groups and rename index
pop_groups_df = crime_data_df.loc[:, ['population_group_code', 'population_group_description']].groupby('population_group_code').first()
pop_groups_final_df = pop_groups_df.rename(columns={'population_group_description': 'population_group'})

# Code Reference: https://stackoverflow.com/questions/21295334/find-length-of-longest-string-in-pandas-dataframe-column
print(f"Max column size - population_group: {pop_groups_final_df['population_group'].map(lambda x: len(x)).max()}")

pop_groups_final_df
# Out:
# Max column size - population_group: 67
#                                                         population_group
# population_group_code
# 0                      Possessions (Puerto Rico, Guam, Virgin Islands...
# 2                                       Cities from 100,000 thru 249,999
# 3                                         Cities from 50,000 thru 99,999
# 4                                         Cities from 25,000 thru 49,999
# 5                                         Cities from 10,000 thru 24,999
# 6                                           Cities from 2,500 thru 9,999
# 7                                                     Cities under 2,500
# 1A                                              Cities 1,000,000 or over
# 1B                                      Cities from 500,000 thru 999,999
# 1C                                      Cities from 250,000 thru 499,999
# 8A                                      Non-MSA counties 100,000 or over
# 8B                              Non-MSA counties from 25,000 thru 99,999
# 8C                              Non-MSA counties from 10,000 thru 24,999
# 8D                                         Non-MSA counties under 10,000
# 8E                                                  Non-MSA State Police
# 9A                                          MSA counties 100,000 or over
# 9B                                  MSA counties from 25,000 thru 99,999
# 9C                                  MSA counties from 10,000 thru 24,999
# 9D                                             MSA counties under 10,000
# 9E                                                      MSA State Police

# %%
# Export dataframe to csv 
pop_groups_df.to_csv('data/population_groups.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %% [markdown]
# ### Table: race

# %%
# Create dataframe for race and rename index
race_df = pd.DataFrame(crime_data_df['offender_race'].unique(), columns=['race'])
race_df.index.name = 'race_id'
race_df

# Code Reference: https://stackoverflow.com/questions/21295334/find-length-of-longest-string-in-pandas-dataframe-column
print(f"Max column size - race_id: {race_df['race'].map(lambda x: len(x)).max()}")

race_df
# Out:
# Max column size - race_id: 41
#                                               race
# race_id
# 0                                            White
# 1                                          Unknown
# 2                                         Multiple
# 3                                            Asian
# 4                 American Indian or Alaska Native
# 5                        Black or African American
# 6        Native Hawaiian or Other Pacific Islander
# 7                                    Not Specified

# %%
# Organize and clean up dataframe 
# Order rows to match US census ordering
race_df = race_df.rename(index={5:1, 4: 2, 6: 4, 2: 5, 1: 6}).sort_index()
race_df.loc[6] = 'Unknown or Not Specified'
race_df = race_df.drop([7])
race_df
# Out:
#                                               race
# race_id
# 0                                            White
# 1                        Black or African American
# 2                 American Indian or Alaska Native
# 3                                            Asian
# 4        Native Hawaiian or Other Pacific Islander
# 5                                         Multiple
# 6                         Unknown or Not Specified

# %%
# Export dataframe to csv 
race_df.to_csv('data/race.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %% [markdown]
# ### Table: Victim type

# %%
# Create dataframe with index victim_type
victim_types_df = pd.DataFrame(crime_data_df['victim_types'].str.split(';')).explode('victim_types')
victim_types_df = victim_types_df.rename(columns={'victim_types': 'victim_type'})
victim_types_df = victim_types_df['victim_type'].unique()
victim_types_df = pd.DataFrame(victim_types_df, columns=['victim_type'])
victim_types_df.index.name = 'victim_type_id'
#victim_types_df = victim_types_df.rename(index={5:7, 7: 5, 6: 8, 8: 6}).sort_index()
#victim_types_df.loc[7] = 'Other or Unknown' 
#victim_types_df = victim_types_df.drop([8])
victim_types_df
# Out:
#                             victim_type
# victim_type_id
# 0                            Individual
# 1                Religious Organization
# 2                            Government
# 3                        Society/Public
# 4                              Business
# 5                                 Other
# 6                               Unknown
# 7                 Financial Institution
# 8               Law Enforcement Officer

# %%
# Export dataframe to csv 
victim_types_df.to_csv('data/victim_types.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %% [markdown]
# ### Table: Incident Victim Types

# %%
# Read victim_type csv to DataFrame
victim_type_df = pd.read_csv('data/victim_types.csv')
victim_type_df.head()
# Out:
#    victim_type_id             victim_type
# 0               0              Individual
# 1               1  Religious Organization
# 2               2              Government
# 3               3          Society/Public
# 4               4                Business

# %%
incident_victim_type = pd.DataFrame(crime_data_df['victim_types'].str.split(';')).explode('victim_types').rename(columns={'victim_types': 'victim_type'})
incident_victim_type['incident_id'] = incident_victim_type.index
incident_victim_type
# Out:
#             victim_type  incident_id
# incident_id
# 141003       Individual       141003
# 141004       Individual       141004
# 141005       Individual       141005
# 141006       Individual       141006
# 141007       Individual       141007
# ...                 ...          ...
# 1445630      Individual      1445630
# 1448544      Individual      1448544
# 1448545      Individual      1448545
# 1448546        Business      1448546
# 1448546      Individual      1448546
#
# [90950 rows x 2 columns]

# %%
incident_victim_composite = incident_victim_type.merge(victim_type_df,on = 'victim_type', how = 'left')
incident_victim_composite = incident_victim_composite[['incident_id', 'victim_type_id']]
incident_victim_composite
# Out:
#        incident_id  victim_type_id
# 0           141003               0
# 1           141004               0
# 2           141005               0
# 3           141006               0
# 4           141007               0
# ...            ...             ...
# 90945      1445630               0
# 90946      1448544               0
# 90947      1448545               0
# 90948      1448546               4
# 90949      1448546               0
#
# [90950 rows x 2 columns]

# %%
incident_victim_composite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90950 entries, 0 to 90949
# Data columns (total 2 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   incident_id     90950 non-null  int64
#  1   victim_type_id  90950 non-null  int64
# dtypes: int64(2)
# memory usage: 1.4 MB

# %%
# Export dataframe to csv 
incident_victim_composite.to_csv('data/incident_victim_types.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %% [markdown]
# ### Table: incidents

# %%
# create DataFrame and drop unneeded columns
incident_df = pd.DataFrame(crime_data_df)
incident_df['incident_id'] = incident_df.index
incident_df = incident_df[['incident_id', 'offender_race', 'pug_agency_name', 'ori', 'state_abbr', 'population_group_code', 'incident_date', 
                           'adult_victim_count', 'juvenile_victim_count','total_offender_count', 'adult_offender_count',
                           'juvenile_offender_count', 'victim_count', 'total_individual_victims']]

#in offender_race column change 'Unknown' and 'Not Specified' values to 'Unknown or Not Specified'
replace_values = {'Unknown': 'Unknown or Not Specified', 'Not Specified': 'Unknown or Not Specified'}
incident_df['offender_race'] = incident_df['offender_race'].replace(replace_values)
incident_df = incident_df.rename(columns={'pug_agency_name': 'agency'})
incident_df.head(10)
# Out:
#              incident_id                     offender_race     agency  \
# incident_id
# 141003            141003                             White  Anchorage
# 141004            141004          Unknown or Not Specified  Anchorage
# 141005            141005                             White  Anchorage
# 141006            141006                          Multiple  Anchorage
# 141007            141007                             Asian  Anchorage
# 141008            141008                             White  Anchorage
# 141009            141009                          Multiple  Anchorage
# 141010            141010  American Indian or Alaska Native     Bethel
# 141011            141011                          Multiple     Bethel
# 136965            136965                             White     Hoover
#
#                    ori state_abbr population_group_code incident_date  \
# incident_id
# 141003       AK0010100         AK                    1C    2009-02-17
# 141004       AK0010100         AK                    1C    2009-06-30
# 141005       AK0010100         AK                    1C    2009-08-05
# 141006       AK0010100         AK                    1C    2009-08-28
# 141007       AK0010100         AK                    1C    2009-08-28
# 141008       AK0010100         AK                    1C    2009-11-07
# 141009       AK0010100         AK                    1C    2009-12-16
# 141010       AK0011300         AK                     6    2009-05-04
# 141011       AK0011300         AK                     6    2009-10-05
# 136965       AL0011200         AL                     3    2009-03-06
#
#              adult_victim_count  juvenile_victim_count  total_offender_count  \
# incident_id
# 141003                      NaN                    NaN                     1
# 141004                      NaN                    NaN                     0
# 141005                      NaN                    NaN                     2
# 141006                      NaN                    NaN                     3
# 141007                      NaN                    NaN                     2
# 141008                      NaN                    NaN                     1
# 141009                      NaN                    NaN                     4
# 141010                      NaN                    NaN                     1
# 141011                      NaN                    NaN                     2
# 136965                      NaN                    NaN                     1
#
#              adult_offender_count  juvenile_offender_count  victim_count  \
# incident_id
# 141003                        NaN                      NaN             1
# 141004                        NaN                      NaN             1
# 141005                        NaN                      NaN             1
# 141006                        NaN                      NaN             4
# 141007                        NaN                      NaN             1
# 141008                        NaN                      NaN             1
# 141009                        NaN                      NaN             1
# 141010                        NaN                      NaN             1
# 141011                        NaN                      NaN             1
# 136965                        NaN                      NaN             2
#
#              total_individual_victims
# incident_id
# 141003                            1.0
# 141004                            1.0
# 141005                            1.0
# 141006                            4.0
# 141007                            1.0
# 141008                            1.0
# 141009                            1.0
# 141010                            1.0
# 141011                            1.0
# 136965                            2.0

# %%
race_df = pd.read_csv('data/race.csv')
race_df = race_df.rename(columns={'race_id': 'offender_race_id',
                                  'race': 'offender_race'})
race_df
# Out:
#    offender_race_id                              offender_race
# 0                 0                                      White
# 1                 1                  Black or African American
# 2                 2           American Indian or Alaska Native
# 3                 3                                      Asian
# 4                 4  Native Hawaiian or Other Pacific Islander
# 5                 5                                   Multiple
# 6                 6                   Unknown or Not Specified
# 7                -1                                  All Races

# %%
merged_incident_df = incident_df.merge(race_df, on='offender_race', how = 'left')
merged_incident_df
# Out:
#        incident_id             offender_race       agency        ori  \
# 0           141003                     White    Anchorage  AK0010100
# 1           141004  Unknown or Not Specified    Anchorage  AK0010100
# 2           141005                     White    Anchorage  AK0010100
# 3           141006                  Multiple    Anchorage  AK0010100
# 4           141007                     Asian    Anchorage  AK0010100
# ...            ...                       ...          ...        ...
# 89400      1445214                     White         Cody  WY0150100
# 89401      1445630  Unknown or Not Specified     Riverton  WY0070200
# 89402      1448544                     White  Green River  WY0190100
# 89403      1448545                     White         Park  WY0150000
# 89404      1448546  Unknown or Not Specified     Cheyenne  WY0110100
#
#       state_abbr population_group_code incident_date  adult_victim_count  \
# 0             AK                    1C    2009-02-17                 NaN
# 1             AK                    1C    2009-06-30                 NaN
# 2             AK                    1C    2009-08-05                 NaN
# 3             AK                    1C    2009-08-28                 NaN
# 4             AK                    1C    2009-08-28                 NaN
# ...          ...                   ...           ...                 ...
# 89400         WY                     6    2021-07-01                 0.0
# 89401         WY                     5    2021-09-11                 1.0
# 89402         WY                     5    2021-01-12                 0.0
# 89403         WY                    8C    2021-10-06                 1.0
# 89404         WY                     3    2021-04-22                 1.0
#
#        juvenile_victim_count  total_offender_count  adult_offender_count  \
# 0                        NaN                     1                   NaN
# 1                        NaN                     0                   NaN
# 2                        NaN                     2                   NaN
# 3                        NaN                     3                   NaN
# 4                        NaN                     2                   NaN
# ...                      ...                   ...                   ...
# 89400                    1.0                     1                   1.0
# 89401                    0.0                     0                   NaN
# 89402                    1.0                     1                   0.0
# 89403                    0.0                     1                   1.0
# 89404                    0.0                     0                   NaN
#
#        juvenile_offender_count  victim_count  total_individual_victims  \
# 0                          NaN             1                       1.0
# 1                          NaN             1                       1.0
# 2                          NaN             1                       1.0
# 3                          NaN             4                       4.0
# 4                          NaN             1                       1.0
# ...                        ...           ...                       ...
# 89400                      0.0             1                       1.0
# 89401                      NaN             1                       1.0
# 89402                      1.0             1                       1.0
# 89403                      0.0             1                       1.0
# 89404                      NaN             2                       1.0
#
#        offender_race_id
# 0                     0
# 1                     6
# 2                     0
# 3                     5
# 4                     3
# ...                 ...
# 89400                 0
# 89401                 6
# 89402                 0
# 89403                 0
# 89404                 6
#
# [89405 rows x 15 columns]

# %%
agencies_df = pd.read_csv('data/agencies.csv')
agencies_df
# Out:
#       agency_id        agency
# 0             0     Anchorage
# 1             1        Bethel
# 2             2        Hoover
# 3             3        Mobile
# 4             4      Leesburg
# ...         ...           ...
# 5308       5308    Fall Creek
# 5309       5309        Monona
# 5310       5310    Two Rivers
# 5311       5311    Ronceverte
# 5312       5312  Rock Springs
#
# [5313 rows x 2 columns]

# %%
merged_incident_df = merged_incident_df.merge(agencies_df, on='agency', how = 'left')
merged_incident_df
# Out:
#        incident_id             offender_race       agency        ori  \
# 0           141003                     White    Anchorage  AK0010100
# 1           141004  Unknown or Not Specified    Anchorage  AK0010100
# 2           141005                     White    Anchorage  AK0010100
# 3           141006                  Multiple    Anchorage  AK0010100
# 4           141007                     Asian    Anchorage  AK0010100
# ...            ...                       ...          ...        ...
# 89400      1445214                     White         Cody  WY0150100
# 89401      1445630  Unknown or Not Specified     Riverton  WY0070200
# 89402      1448544                     White  Green River  WY0190100
# 89403      1448545                     White         Park  WY0150000
# 89404      1448546  Unknown or Not Specified     Cheyenne  WY0110100
#
#       state_abbr population_group_code incident_date  adult_victim_count  \
# 0             AK                    1C    2009-02-17                 NaN
# 1             AK                    1C    2009-06-30                 NaN
# 2             AK                    1C    2009-08-05                 NaN
# 3             AK                    1C    2009-08-28                 NaN
# 4             AK                    1C    2009-08-28                 NaN
# ...          ...                   ...           ...                 ...
# 89400         WY                     6    2021-07-01                 0.0
# 89401         WY                     5    2021-09-11                 1.0
# 89402         WY                     5    2021-01-12                 0.0
# 89403         WY                    8C    2021-10-06                 1.0
# 89404         WY                     3    2021-04-22                 1.0
#
#        juvenile_victim_count  total_offender_count  adult_offender_count  \
# 0                        NaN                     1                   NaN
# 1                        NaN                     0                   NaN
# 2                        NaN                     2                   NaN
# 3                        NaN                     3                   NaN
# 4                        NaN                     2                   NaN
# ...                      ...                   ...                   ...
# 89400                    1.0                     1                   1.0
# 89401                    0.0                     0                   NaN
# 89402                    1.0                     1                   0.0
# 89403                    0.0                     1                   1.0
# 89404                    0.0                     0                   NaN
#
#        juvenile_offender_count  victim_count  total_individual_victims  \
# 0                          NaN             1                       1.0
# 1                          NaN             1                       1.0
# 2                          NaN             1                       1.0
# 3                          NaN             4                       4.0
# 4                          NaN             1                       1.0
# ...                        ...           ...                       ...
# 89400                      0.0             1                       1.0
# 89401                      NaN             1                       1.0
# 89402                      1.0             1                       1.0
# 89403                      0.0             1                       1.0
# 89404                      NaN             2                       1.0
#
#        offender_race_id  agency_id
# 0                     0          0
# 1                     6          0
# 2                     0          0
# 3                     5          0
# 4                     3          0
# ...                 ...        ...
# 89400                 0       4737
# 89401                 6       1743
# 89402                 0       1744
# 89403                 0        338
# 89404                 6       3230
#
# [89405 rows x 16 columns]
