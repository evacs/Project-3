# %% [markdown]
# # Extract, Transform and Load data

# %%
# Import dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# ### Extract the hate crime data

# %%
# Read the data into a Pandas DataFrame
hcrime_df = pd.read_csv('../resources/fbi_hate_crime_data.csv')
hcrime_df.head()
# Out:
#    incident_id  data_year        ori    pug_agency_name pub_agency_unit  \
# 0           43       1991  AR0350100         Pine Bluff             NaN
# 1           44       1991  AR0350100         Pine Bluff             NaN
# 2           45       1991  AR0600300  North Little Rock             NaN
# 3           46       1991  AR0600300  North Little Rock             NaN
# 4           47       1991  AR0670000             Sevier             NaN
#
#   agency_type_name state_abbr state_name       division_name region_name  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4           County         AR   Arkansas  West South Central       South  ...
#
#                offender_race offender_ethnicity victim_count  \
# 0  Black or African American      Not Specified            1
# 1  Black or African American      Not Specified            2
# 2  Black or African American      Not Specified            2
# 3  Black or African American      Not Specified            1
# 4                      White      Not Specified            1
#
#                                         offense_name  \
# 0                                 Aggravated Assault
# 1  Aggravated Assault;Destruction/Damage/Vandalis...
# 2  Aggravated Assault;Murder and Nonnegligent Man...
# 3                                       Intimidation
# 4                                       Intimidation
#
#    total_individual_victims                       location_name  \
# 0                       1.0                      Residence/Home
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       2.0                      Residence/Home
# 3                       1.0                      Residence/Home
# 4                       1.0                      School/College
#
#                         bias_desc  victim_types multiple_offense multiple_bias
# 0  Anti-Black or African American    Individual                S             S
# 1                      Anti-White    Individual                M             S
# 2                      Anti-White    Individual                M             S
# 3                      Anti-White    Individual                S             S
# 4  Anti-Black or African American    Individual                S             S
#
# [5 rows x 28 columns]

# %%
hcrime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226328 entries, 0 to 226327
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   incident_id                   226328 non-null  int64
#  1   data_year                     226328 non-null  int64
#  2   ori                           226328 non-null  object
#  3   pug_agency_name               226328 non-null  object
#  4   pub_agency_unit               6563 non-null    object
#  5   agency_type_name              226328 non-null  object
#  6   state_abbr                    226328 non-null  object
#  7   state_name                    226328 non-null  object
#  8   division_name                 226328 non-null  object
#  9   region_name                   226328 non-null  object
#  10  population_group_code         225924 non-null  object
#  11  population_group_description  225924 non-null  object
#  12  incident_date                 226328 non-null  object
#  13  adult_victim_count            58203 non-null   float64
#  14  juvenile_victim_count         56331 non-null   float64
#  15  total_offender_count          226328 non-null  int64
#  16  adult_offender_count          53462 non-null   float64
#  17  juvenile_offender_count       53455 non-null   float64
#  18  offender_race                 226328 non-null  object
#  19  offender_ethnicity            226328 non-null  object
#  20  victim_count                  226328 non-null  int64
#  21  offense_name                  226328 non-null  object
#  22  total_individual_victims      222849 non-null  float64
#  23  location_name                 226328 non-null  object
#  24  bias_desc                     226328 non-null  object
#  25  victim_types                  226328 non-null  object
#  26  multiple_offense              226328 non-null  object
#  27  multiple_bias                 226328 non-null  object
# dtypes: float64(5), int64(4), object(19)
# memory usage: 48.3+ MB

# %%
# Remove data before 2009
crime_data_df = hcrime_df[hcrime_df['data_year'] > 2008]

# Display sample data
crime_data_df.head()
# Out:
#         incident_id  data_year        ori pug_agency_name pub_agency_unit  \
# 136923       141003       2009  AK0010100       Anchorage             NaN
# 136924       141004       2009  AK0010100       Anchorage             NaN
# 136925       141005       2009  AK0010100       Anchorage             NaN
# 136926       141006       2009  AK0010100       Anchorage             NaN
# 136927       141007       2009  AK0010100       Anchorage             NaN
#
#        agency_type_name state_abbr state_name division_name region_name  ...  \
# 136923             City         AK     Alaska       Pacific        West  ...
# 136924             City         AK     Alaska       Pacific        West  ...
# 136925             City         AK     Alaska       Pacific        West  ...
# 136926             City         AK     Alaska       Pacific        West  ...
# 136927             City         AK     Alaska       Pacific        West  ...
#
#        offender_race offender_ethnicity victim_count        offense_name  \
# 136923         White      Not Specified            1      Simple Assault
# 136924       Unknown      Not Specified            1        Intimidation
# 136925         White      Not Specified            1             Robbery
# 136926      Multiple      Not Specified            4  Aggravated Assault
# 136927         Asian      Not Specified            1             Robbery
#
#         total_individual_victims                       location_name  \
# 136923                       1.0  Highway/Road/Alley/Street/Sidewalk
# 136924                       1.0                      Residence/Home
# 136925                       1.0  Highway/Road/Alley/Street/Sidewalk
# 136926                       4.0  Highway/Road/Alley/Street/Sidewalk
# 136927                       1.0  Highway/Road/Alley/Street/Sidewalk
#
#                                                 bias_desc  victim_types  \
# 136923              Anti-American Indian or Alaska Native    Individual
# 136924  Anti-Lesbian, Gay, Bisexual, or Transgender (M...    Individual
# 136925              Anti-American Indian or Alaska Native    Individual
# 136926              Anti-American Indian or Alaska Native    Individual
# 136927              Anti-American Indian or Alaska Native    Individual
#
#        multiple_offense multiple_bias
# 136923                S             S
# 136924                S             S
# 136925                S             S
# 136926                S             S
# 136927                S             S
#
# [5 rows x 28 columns]

# %%
filtered_df = crime_data_df[crime_data_df["multiple_bias"]=="M"]
filtered_df["bias_desc"] =filtered_df["bias_desc"].str.split(';')
explode_df = filtered_df.explode("bias_desc", ignore_index=True)
explode_df.head(20)
# Out:
# C:\Users\tnord\AppData\Local\Temp\ipykernel_6120\2926941041.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["bias_desc"] =filtered_df["bias_desc"].str.split(';')
#     incident_id  data_year        ori      pug_agency_name pub_agency_unit  \
# 0        137625       2009  CA0411300         Redwood City             NaN
# 1        137625       2009  CA0411300         Redwood City             NaN
# 2        141419       2009  CO0070400             Longmont             NaN
# 3        141419       2009  CO0070400             Longmont             NaN
# 4        137918       2009  CT0015500        West Hartford             NaN
# 5        137918       2009  CT0015500        West Hartford             NaN
# 6        138428       2009  KY0470400           West Point             NaN
# 7        138428       2009  KY0470400           West Point             NaN
# 8        140343       2009  SC0130500             Pageland             NaN
# 9        140343       2009  SC0130500             Pageland             NaN
# 10       141778       2009  WV0060400  Marshall University             NaN
# 11       141778       2009  WV0060400  Marshall University             NaN
# 12       144737       2010  ID0280100        Coeur d'Alene             NaN
# 13       144737       2010  ID0280100        Coeur d'Alene             NaN
# 14       146615       2010  OH0250400              Gahanna             NaN
# 15       146615       2010  OH0250400              Gahanna             NaN
# 16       149130       2010  OH0770100                Akron             NaN
# 17       149130       2010  OH0770100                Akron             NaN
# 18       148792       2010  WA0380300              Pullman             NaN
# 19       148792       2010  WA0380300              Pullman             NaN
#
#          agency_type_name state_abbr      state_name       division_name  \
# 0                    City         CA      California             Pacific
# 1                    City         CA      California             Pacific
# 2                    City         CO        Colorado            Mountain
# 3                    City         CO        Colorado            Mountain
# 4                    City         CT     Connecticut         New England
# 5                    City         CT     Connecticut         New England
# 6                    City         KY        Kentucky  East South Central
# 7                    City         KY        Kentucky  East South Central
# 8                    City         SC  South Carolina      South Atlantic
# 9                    City         SC  South Carolina      South Atlantic
# 10  University or College         WV   West Virginia      South Atlantic
# 11  University or College         WV   West Virginia      South Atlantic
# 12                   City         ID           Idaho            Mountain
# 13                   City         ID           Idaho            Mountain
# 14                   City         OH            Ohio  East North Central
# 15                   City         OH            Ohio  East North Central
# 16                   City         OH            Ohio  East North Central
# 17                   City         OH            Ohio  East North Central
# 18                   City         WA      Washington             Pacific
# 19                   City         WA      Washington             Pacific
#
#    region_name  ... offender_race offender_ethnicity victim_count  \
# 0         West  ...       Unknown      Not Specified            2
# 1         West  ...       Unknown      Not Specified            2
# 2         West  ...         White      Not Specified            2
# 3         West  ...         White      Not Specified            2
# 4    Northeast  ...         White      Not Specified            2
# 5    Northeast  ...         White      Not Specified            2
# 6        South  ...         White      Not Specified            4
# 7        South  ...         White      Not Specified            4
# 8        South  ...       Unknown      Not Specified            2
# 9        South  ...       Unknown      Not Specified            2
# 10       South  ...      Multiple      Not Specified            2
# 11       South  ...      Multiple      Not Specified            2
# 12        West  ...         White      Not Specified            3
# 13        West  ...         White      Not Specified            3
# 14     Midwest  ...       Unknown      Not Specified            2
# 15     Midwest  ...       Unknown      Not Specified            2
# 16     Midwest  ...      Multiple      Not Specified            2
# 17     Midwest  ...      Multiple      Not Specified            2
# 18        West  ...       Unknown      Not Specified            2
# 19        West  ...       Unknown      Not Specified            2
#
#                                          offense_name  \
# 0   Destruction/Damage/Vandalism of Property;Intim...
# 1   Destruction/Damage/Vandalism of Property;Intim...
# 2   Burglary/Breaking & Entering;Destruction/Damag...
# 3   Burglary/Breaking & Entering;Destruction/Damag...
# 4   Destruction/Damage/Vandalism of Property;Intim...
# 5   Destruction/Damage/Vandalism of Property;Intim...
# 6                         Intimidation;Simple Assault
# 7                         Intimidation;Simple Assault
# 8   Burglary/Breaking & Entering;Destruction/Damag...
# 9   Burglary/Breaking & Entering;Destruction/Damag...
# 10                  Aggravated Assault;Simple Assault
# 11                  Aggravated Assault;Simple Assault
# 12                  Aggravated Assault;Simple Assault
# 13                  Aggravated Assault;Simple Assault
# 14  All Other Larceny;Destruction/Damage/Vandalism...
# 15  All Other Larceny;Destruction/Damage/Vandalism...
# 16  Aggravated Assault;Destruction/Damage/Vandalis...
# 17  Aggravated Assault;Destruction/Damage/Vandalis...
# 18  All Other Larceny;Destruction/Damage/Vandalism...
# 19  All Other Larceny;Destruction/Damage/Vandalism...
#
#     total_individual_victims  \
# 0                        1.0
# 1                        1.0
# 2                        0.0
# 3                        0.0
# 4                        2.0
# 5                        2.0
# 6                        4.0
# 7                        4.0
# 8                        2.0
# 9                        2.0
# 10                       2.0
# 11                       2.0
# 12                       3.0
# 13                       3.0
# 14                       2.0
# 15                       2.0
# 16                       2.0
# 17                       2.0
# 18                       2.0
# 19                       2.0
#
#                                         location_name  \
# 0                                      Residence/Home
# 1                                      Residence/Home
# 2                                          Restaurant
# 3                                          Restaurant
# 4                                      Residence/Home
# 5                                      Residence/Home
# 6   Highway/Road/Alley/Street/Sidewalk;Jail/Prison...
# 7   Highway/Road/Alley/Street/Sidewalk;Jail/Prison...
# 8   Highway/Road/Alley/Street/Sidewalk;Residence/Home
# 9   Highway/Road/Alley/Street/Sidewalk;Residence/Home
# 10                                     School/College
# 11                                     School/College
# 12                                      Bar/Nightclub
# 13                                      Bar/Nightclub
# 14                                     Residence/Home
# 15                                     Residence/Home
# 16                                     School/College
# 17                                     School/College
# 18  Highway/Road/Alley/Street/Sidewalk;Residence/Home
# 19  Highway/Road/Alley/Street/Sidewalk;Residence/Home
#
#                                             bias_desc  victim_types  \
# 0                      Anti-Black or African American    Individual
# 1                          Anti-Multiple Races, Group    Individual
# 2                             Anti-Hispanic or Latino      Business
# 3                  Anti-Other Race/Ethnicity/Ancestry      Business
# 4                                     Anti-Gay (Male)    Individual
# 5                  Anti-Other Race/Ethnicity/Ancestry    Individual
# 6                                          Anti-Asian    Individual
# 7                      Anti-Black or African American    Individual
# 8                                     Anti-Gay (Male)    Individual
# 9   Anti-Lesbian, Gay, Bisexual, or Transgender (M...    Individual
# 10                     Anti-Black or African American    Individual
# 11                                         Anti-White    Individual
# 12                         Anti-Multiple Races, Group    Individual
# 13                                Anti-Other Religion    Individual
# 14                                    Anti-Gay (Male)    Individual
# 15                         Anti-Multiple Races, Group    Individual
# 16                                         Anti-Asian    Individual
# 17                 Anti-Other Race/Ethnicity/Ancestry    Individual
# 18                                         Anti-Asian    Individual
# 19                     Anti-Black or African American    Individual
#
#    multiple_offense multiple_bias
# 0                 M             M
# 1                 M             M
# 2                 M             M
# 3                 M             M
# 4                 M             M
# 5                 M             M
# 6                 M             M
# 7                 M             M
# 8                 M             M
# 9                 M             M
# 10                M             M
# 11                M             M
# 12                M             M
# 13                M             M
# 14                M             M
# 15                M             M
# 16                M             M
# 17                M             M
# 18                M             M
# 19                M             M
#
# [20 rows x 28 columns]

# %%
explode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2411 entries, 0 to 2410
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   incident_id                   2411 non-null   int64
#  1   data_year                     2411 non-null   int64
#  2   ori                           2411 non-null   object
#  3   pug_agency_name               2411 non-null   object
#  4   pub_agency_unit               99 non-null     object
#  5   agency_type_name              2411 non-null   object
#  6   state_abbr                    2411 non-null   object
#  7   state_name                    2411 non-null   object
#  8   division_name                 2411 non-null   object
#  9   region_name                   2411 non-null   object
#  10  population_group_code         2358 non-null   object
#  11  population_group_description  2358 non-null   object
#  12  incident_date                 2411 non-null   object
#  13  adult_victim_count            1864 non-null   float64
#  14  juvenile_victim_count         1429 non-null   float64
#  15  total_offender_count          2411 non-null   int64
#  16  adult_offender_count          1974 non-null   float64
#  17  juvenile_offender_count       1972 non-null   float64
#  18  offender_race                 2411 non-null   object
#  19  offender_ethnicity            2411 non-null   object
#  20  victim_count                  2411 non-null   int64
#  21  offense_name                  2411 non-null   object
#  22  total_individual_victims      2014 non-null   float64
#  23  location_name                 2411 non-null   object
#  24  bias_desc                     2411 non-null   object
#  25  victim_types                  2411 non-null   object
#  26  multiple_offense              2411 non-null   object
#  27  multiple_bias                 2411 non-null   object
# dtypes: float64(5), int64(4), object(19)
# memory usage: 527.5+ KB

# %%
filtered_df2 = crime_data_df[crime_data_df["multiple_bias"]=="S"]
final_df = filtered_df2.merge(explode_df,how ='outer')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90701 entries, 0 to 90700
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   incident_id                   90701 non-null  int64
#  1   data_year                     90701 non-null  int64
#  2   ori                           90701 non-null  object
#  3   pug_agency_name               90701 non-null  object
#  4   pub_agency_unit               2958 non-null   object
#  5   agency_type_name              90701 non-null  object
#  6   state_abbr                    90701 non-null  object
#  7   state_name                    90701 non-null  object
#  8   division_name                 90701 non-null  object
#  9   region_name                   90701 non-null  object
#  10  population_group_code         90270 non-null  object
#  11  population_group_description  90270 non-null  object
#  12  incident_date                 90701 non-null  object
#  13  adult_victim_count            59194 non-null  float64
#  14  juvenile_victim_count         57084 non-null  float64
#  15  total_offender_count          90701 non-null  int64
#  16  adult_offender_count          54525 non-null  float64
#  17  juvenile_offender_count       54517 non-null  float64
#  18  offender_race                 90701 non-null  object
#  19  offender_ethnicity            90701 non-null  object
#  20  victim_count                  90701 non-null  int64
#  21  offense_name                  90701 non-null  object
#  22  total_individual_victims      87000 non-null  float64
#  23  location_name                 90701 non-null  object
#  24  bias_desc                     90701 non-null  object
#  25  victim_types                  90701 non-null  object
#  26  multiple_offense              90701 non-null  object
#  27  multiple_bias                 90701 non-null  object
# dtypes: float64(5), int64(4), object(19)
# memory usage: 20.1+ MB

# %%
# Export the DataFrame as a CSV file. 
final_df.to_csv("resources/hate_crime.csv", index=False)

# %% [markdown]
# ## Creating Categories for Biases

# %%
Sexual_orientation = ['Anti-Gay (Male)','Anti-Lesbian (Female)','Anti-Lesbian, Gay, Bisexual, or Transgender (Mixed Group)','Anti-Bisexual','Anti-Heterosexual']
Religion = ['Anti-Jewish','Anti-Arab', 'Anti-Protestant', 'Anti-Other Religion','Anti-Islamic (Muslim)', 'Anti-Catholic', 'Anti-Multiple Religions, Group','Anti-Atheism/Agnosticism','Anti-Buddhist', 'Anti-Sikh', 'Anti-Other Christian', 'Anti-Hindu','Anti-Eastern Orthodox (Russian, Greek, Other)',"Anti-Jehovah's Witness", 'Anti-Church of Jesus Christ']
Race_Ethnicity_Ancestry = ['Anti-Black or African American', 'Anti-White','Anti-Arab','Anti-Asian','Anti-Hispanic or Latino', 'Anti-Multiple Races, Group','Anti-Other Race/Ethnicity/Ancestry','Anti-American Indian or Alaska Native','Anti-Native Hawaiian or Other Pacific Islander']
Gender_identity = ['Anti-Gender Non-Conforming','Anti-Transgender']
Gender = ['Anti-Female','Anti-Male']
Disability = ['Anti-Physical Disability', 'Anti-Mental Disability']

# len(Sexual_orientation)
# len(Religion)
# len(Race_Ethnicity_Ancestry)
# len(Gender_identity)
# len(Gender)
# len(Disability)

# %%
data = {'category': "Sexual_orientation", 'bias': Sexual_orientation}
sexual_orientation_df = pd.DataFrame(data, columns = ['category','bias'])
sexual_orientation_df
# Out:
#              category                                               bias
# 0  Sexual_orientation                                    Anti-Gay (Male)
# 1  Sexual_orientation                              Anti-Lesbian (Female)
# 2  Sexual_orientation  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 3  Sexual_orientation                                      Anti-Bisexual
# 4  Sexual_orientation                                  Anti-Heterosexual

# %%
data = {'category': "Religion", 'bias': Religion}
Religion_df = pd.DataFrame(data, columns = ['category','bias'])
Religion_df
# Out:
#     category                                           bias
# 0   Religion                                    Anti-Jewish
# 1   Religion                                      Anti-Arab
# 2   Religion                                Anti-Protestant
# 3   Religion                            Anti-Other Religion
# 4   Religion                          Anti-Islamic (Muslim)
# 5   Religion                                  Anti-Catholic
# 6   Religion                 Anti-Multiple Religions, Group
# 7   Religion                       Anti-Atheism/Agnosticism
# 8   Religion                                  Anti-Buddhist
# 9   Religion                                      Anti-Sikh
# 10  Religion                           Anti-Other Christian
# 11  Religion                                     Anti-Hindu
# 12  Religion  Anti-Eastern Orthodox (Russian, Greek, Other)
# 13  Religion                         Anti-Jehovah's Witness
# 14  Religion                    Anti-Church of Jesus Christ

# %%
data = {'category': "Race_Ethnicity_Ancestry", 'bias': Race_Ethnicity_Ancestry}
Race_Ethnicity_Ancestry_df = pd.DataFrame(data, columns = ['category','bias'])
Race_Ethnicity_Ancestry_df
# Out:
#                   category                                            bias
# 0  Race_Ethnicity_Ancestry                  Anti-Black or African American
# 1  Race_Ethnicity_Ancestry                                      Anti-White
# 2  Race_Ethnicity_Ancestry                                       Anti-Arab
# 3  Race_Ethnicity_Ancestry                                      Anti-Asian
# 4  Race_Ethnicity_Ancestry                         Anti-Hispanic or Latino
# 5  Race_Ethnicity_Ancestry                      Anti-Multiple Races, Group
# 6  Race_Ethnicity_Ancestry              Anti-Other Race/Ethnicity/Ancestry
# 7  Race_Ethnicity_Ancestry           Anti-American Indian or Alaska Native
# 8  Race_Ethnicity_Ancestry  Anti-Native Hawaiian or Other Pacific Islander

# %%
data = {'category': "Gender_identity", 'bias': Gender_identity}
Gender_identity_df = pd.DataFrame(data, columns = ['category','bias'])
Gender_identity_df
# Out:
#           category                        bias
# 0  Gender_identity  Anti-Gender Non-Conforming
# 1  Gender_identity            Anti-Transgender

# %%
data = {'category': "Gender", 'bias': Gender}
Gender_df = pd.DataFrame(data, columns = ['category','bias'])
Gender_df
# Out:
#   category         bias
# 0   Gender  Anti-Female
# 1   Gender    Anti-Male

# %%
data = {'category': "Disability", 'bias': Disability}
Disability_df = pd.DataFrame(data, columns = ['category','bias'])
Disability_df
# Out:
#      category                      bias
# 0  Disability  Anti-Physical Disability
# 1  Disability    Anti-Mental Disability

# %%
bias_df = sexual_orientation_df.merge(Religion_df,how ='outer').merge(Race_Ethnicity_Ancestry_df, how ="outer").merge(Gender_identity_df, how ="outer").merge(Gender_df, how ="outer").merge(Disability_df, how ="outer")

# %%
categories = bias_df["category"].unique().tolist()
# Create dataframe for category
category_df = pd.DataFrame(categories, columns=['category'])
category_df.index.name = 'category_id'
category_df
# Out:
#                             category
# category_id
# 0                 Sexual_orientation
# 1                           Religion
# 2            Race_Ethnicity_Ancestry
# 3                    Gender_identity
# 4                             Gender
# 5                         Disability

# %%
#Saving to csv file
category_df.to_csv("C:/Users/tnord/OneDrive/Desktop/Bootcamp_Projects/Group_Project_3/Project-3/etl/data/bias_categories.csv", index=True)

# %% [markdown]
# ## Biases table

# %%
# Read the data into a Pandas DataFrame
categories= pd.read_csv('data/bias_categories.csv')
categories
# Out:
#    category_id                 category
# 0            0       Sexual_orientation
# 1            1                 Religion
# 2            2  Race_Ethnicity_Ancestry
# 3            3          Gender_identity
# 4            4                   Gender
# 5            5               Disability

# %%
bias = final_df["bias_desc"].unique().tolist()

# %%
# Create dataframe for bias
biases_df = pd.DataFrame(bias, columns=['bias_desc'])
biases_df.index.name = 'bias_id'
biases_df
# Out:
#                                                  bias_desc
# bias_id
# 0                    Anti-American Indian or Alaska Native
# 1        Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 2                                               Anti-White
# 3                                    Anti-Lesbian (Female)
# 4                           Anti-Black or African American
# 5                               Anti-Multiple Races, Group
# 6                                          Anti-Gay (Male)
# 7                                              Anti-Jewish
# 8                                          Anti-Protestant
# 9                                            Anti-Bisexual
# 10                                 Anti-Hispanic or Latino
# 11                                           Anti-Catholic
# 12                                       Anti-Heterosexual
# 13                                Anti-Atheism/Agnosticism
# 14                                   Anti-Islamic (Muslim)
# 15                                  Anti-Mental Disability
# 16                                              Anti-Asian
# 17                      Anti-Other Race/Ethnicity/Ancestry
# 18                                     Anti-Other Religion
# 19                          Anti-Multiple Religions, Group
# 20                                Anti-Physical Disability
# 21                              Anti-Gender Non-Conforming
# 22                                             Anti-Female
# 23                                        Anti-Transgender
# 24          Anti-Native Hawaiian or Other Pacific Islander
# 25                                               Anti-Male
# 26                                               Anti-Arab
# 27                                  Anti-Jehovah's Witness
# 28                             Anti-Church of Jesus Christ
# 29                                           Anti-Buddhist
# 30                                               Anti-Sikh
# 31                                    Anti-Other Christian
# 32                                              Anti-Hindu
# 33           Anti-Eastern Orthodox (Russian, Greek, Other)
# 34               Unknown (offender's motivation not known)

# %%
# Merge dataframes to create bias table with bias_id, bias, category_id
bias = biases_df.merge( bias_df,left_on  = "bias_desc",right_on ="bias", how = 'right').merge(categories,on  = "category", how = 'right')
bias = bias[['bias_desc','category_id']]
bias.index.name = 'bias_id'
bias
# Out:
#                                                  bias_desc  category_id
# bias_id
# 0                                          Anti-Gay (Male)            0
# 1                                    Anti-Lesbian (Female)            0
# 2        Anti-Lesbian, Gay, Bisexual, or Transgender (M...            0
# 3                                            Anti-Bisexual            0
# 4                                        Anti-Heterosexual            0
# 5                                              Anti-Jewish            1
# 6                                                Anti-Arab            1
# 7                                          Anti-Protestant            1
# 8                                      Anti-Other Religion            1
# 9                                    Anti-Islamic (Muslim)            1
# 10                                           Anti-Catholic            1
# 11                          Anti-Multiple Religions, Group            1
# 12                                Anti-Atheism/Agnosticism            1
# 13                                           Anti-Buddhist            1
# 14                                               Anti-Sikh            1
# 15                                    Anti-Other Christian            1
# 16                                              Anti-Hindu            1
# 17           Anti-Eastern Orthodox (Russian, Greek, Other)            1
# 18                                  Anti-Jehovah's Witness            1
# 19                             Anti-Church of Jesus Christ            1
# 20                          Anti-Black or African American            2
# 21                                              Anti-White            2
# 22                                               Anti-Arab            2
# 23                                              Anti-Asian            2
# 24                                 Anti-Hispanic or Latino            2
# 25                              Anti-Multiple Races, Group            2
# 26                      Anti-Other Race/Ethnicity/Ancestry            2
# 27                   Anti-American Indian or Alaska Native            2
# 28          Anti-Native Hawaiian or Other Pacific Islander            2
# 29                              Anti-Gender Non-Conforming            3
# 30                                        Anti-Transgender            3
# 31                                             Anti-Female            4
# 32                                               Anti-Male            4
# 33                                Anti-Physical Disability            5
# 34                                  Anti-Mental Disability            5

# %%
#Saving to csv file
bias.to_csv("data/bias.csv", index=True)

# %% [markdown]
# ### Incidents and locations

# %%
crime_data_df["location_name"] =crime_data_df["location_name"].str.split(';')
explode_df = crime_data_df.explode("location_name", ignore_index=True)
# Out:
# C:\Users\tnord\AppData\Local\Temp\ipykernel_6120\24756533.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   crime_data_df["location_name"] =crime_data_df["location_name"].str.split(';')

# %%
loc_df = explode_df["location_name"].unique()
# Create dataframe for bias
loc_df = pd.DataFrame(loc_df, columns=['location_name'])
loc_df.index.name = 'location_id'
loc_df
# Out:
#                                              location_name
# location_id
# 0                       Highway/Road/Alley/Street/Sidewalk
# 1                                           Residence/Home
# 2                                               Restaurant
# 3                                        Convenience Store
# 4                           Church/Synagogue/Temple/Mosque
# 5                                              Field/Woods
# 6                               Commercial/Office Building
# 7                                            Other/Unknown
# 8                                  Parking/Drop Lot/Garage
# 9                                             Liquor Store
# 10                                   Bank/Savings and Loan
# 11                                 Rental Storage Facility
# 12                                         Specialty Store
# 13                                          School/College
# 14           Jail/Prison/Penitentiary/Corrections Facility
# 15                              Government/Public Building
# 16                               Department/Discount Store
# 17                                           Bar/Nightclub
# 18                                     Lake/Waterway/Beach
# 19                     Drug Store/Doctor's Office/Hospital
# 20                                     Grocery/Supermarket
# 21                                        Hotel/Motel/Etc.
# 22                                  Air/Bus/Train Terminal
# 23                                     Service/Gas Station
# 24                                       Construction Site
# 25                               School-College/University
# 26                             School-Elementary/Secondary
# 27                                         Industrial Site
# 28                     Gambling Facility/Casino/Race Track
# 29                                           Shopping Mall
# 30                                         Camp/Campground
# 31                                         Park/Playground
# 32                                            Tribal Lands
# 33                      Arena/Stadium/Fairgrounds/Coliseum
# 34                                  ATM Separate from Bank
# 35                                           Farm Facility
# 36                                          Amusement Park
# 37                                        Daycare Facility
# 38                                Auto Dealership New/Used
# 39                                               Rest Area
# 40                           Abandoned/Condemned Structure
# 41                                Shelter-Mission/Homeless
# 42                       Dock/Wharf/Freight/Modal Terminal
# 43                                        Community Center
# 44                                   Military Installation
# 45                                              Cyberspace

# %%
#Saving to csv file
loc_df.to_csv("data/location.csv", index=True)

# %% [markdown]
# ## Incident locations

# %%
# Read the data into a Pandas DataFrame
location_df = pd.read_csv('data/location.csv')
location_df.head()
# Out:
#    location_id                       location_name
# 0            0  Highway/Road/Alley/Street/Sidewalk
# 1            1                      Residence/Home
# 2            2                          Restaurant
# 3            3                   Convenience Store
# 4            4      Church/Synagogue/Temple/Mosque

# %%
inci_df = explode_df[['incident_id','location_name']]

# %%
incident_locations = inci_df.merge( location_df,on  = "location_name", how = 'right')

# %%
incident_locations = incident_locations[["incident_id","location_id"]]
incident_locations.head()
# Out:
#    incident_id  location_id
# 0       141003            0
# 1       141005            0
# 2       141006            0
# 3       141007            0
# 4       141008            0

# %%
#Saving to csv file
incident_locations.to_csv("data/incident_location.csv", index=False)

# %% [markdown]
# ## Incident Biases

# %%
# Read the data into a Pandas DataFrame
bias = pd.read_csv('data/bias.csv')
bias.head()
# Out:
#    bias_id                                          bias_desc  category_id
# 0        0                                    Anti-Gay (Male)            0
# 1        1                              Anti-Lesbian (Female)            0
# 2        2  Anti-Lesbian, Gay, Bisexual, or Transgender (M...            0
# 3        3                                      Anti-Bisexual            0
# 4        4                                  Anti-Heterosexual            0

# %%
incident = final_df[['incident_id','bias_desc']]
incident_biases = incident.merge( bias, on  = "bias_desc", how = 'right')
incident_biases = incident_biases[["incident_id","bias_id"]]
incident_biases.head()
# Out:
#    incident_id  bias_id
# 0       136967        0
# 1       137125        0
# 2       137131        0
# 3       137151        0
# 4       137156        0

# %%
#Saving to csv file
incident_biases.to_csv("data/incident_biases.csv", index=False)
