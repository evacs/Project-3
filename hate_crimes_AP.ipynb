# %%
#adding dependedncies
import pandas as pd
import numpy as np

# %%
#importing data
crime_data_df = pd.read_excel('resources/hate_crimes_from_FBI.xlsx')
crime_data_df.head()
# Out:
#    incident_id  data_year        ori    pug_agency_name pub_agency_unit  \
# 0           43       1991  AR0350100         Pine Bluff             NaN
# 1           44       1991  AR0350100         Pine Bluff             NaN
# 2           45       1991  AR0600300  North Little Rock             NaN
# 3           46       1991  AR0600300  North Little Rock             NaN
# 4           47       1991  AR0670000             Sevier             NaN
#
#   agency_type_name state_abbr state_name       division_name region_name  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4           County         AR   Arkansas  West South Central       South  ...
#
#                offender_race offender_ethnicity victim_count  \
# 0  Black or African American      Not Specified            1
# 1  Black or African American      Not Specified            2
# 2  Black or African American      Not Specified            2
# 3  Black or African American      Not Specified            1
# 4                      White      Not Specified            1
#
#                                         offense_name  \
# 0                                 Aggravated Assault
# 1  Aggravated Assault;Destruction/Damage/Vandalis...
# 2  Aggravated Assault;Murder and Nonnegligent Man...
# 3                                       Intimidation
# 4                                       Intimidation
#
#    total_individual_victims                       location_name  \
# 0                       1.0                      Residence/Home
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       2.0                      Residence/Home
# 3                       1.0                      Residence/Home
# 4                       1.0                      School/College
#
#                         bias_desc  victim_types multiple_offense multiple_bias
# 0  Anti-Black or African American    Individual                S             S
# 1                      Anti-White    Individual                M             S
# 2                      Anti-White    Individual                M             S
# 3                      Anti-White    Individual                S             S
# 4  Anti-Black or African American    Individual                S             S
#
# [5 rows x 28 columns]

# %%
#removing unneeded columns
crime_data_df = crime_data_df[['incident_id', 'data_year', 'pug_agency_name', 'agency_type_name', 'state_abbr', 
                               'state_name', 'division_name', 'region_name', 'offender_race', 
                               'offender_ethnicity', 'victim_count', 'offense_name', 'total_individual_victims',
                              'location_name', 'bias_desc', 'victim_types', 'multiple_offense', 'multiple_bias']]
crime_data_df.head()
# Out:
#    incident_id  data_year    pug_agency_name agency_type_name state_abbr  \
# 0           43       1991         Pine Bluff             City         AR
# 1           44       1991         Pine Bluff             City         AR
# 2           45       1991  North Little Rock             City         AR
# 3           46       1991  North Little Rock             City         AR
# 4           47       1991             Sevier           County         AR
#
#   state_name       division_name region_name              offender_race  \
# 0   Arkansas  West South Central       South  Black or African American
# 1   Arkansas  West South Central       South  Black or African American
# 2   Arkansas  West South Central       South  Black or African American
# 3   Arkansas  West South Central       South  Black or African American
# 4   Arkansas  West South Central       South                      White
#
#   offender_ethnicity  victim_count  \
# 0      Not Specified             1
# 1      Not Specified             2
# 2      Not Specified             2
# 3      Not Specified             1
# 4      Not Specified             1
#
#                                         offense_name  \
# 0                                 Aggravated Assault
# 1  Aggravated Assault;Destruction/Damage/Vandalis...
# 2  Aggravated Assault;Murder and Nonnegligent Man...
# 3                                       Intimidation
# 4                                       Intimidation
#
#    total_individual_victims                       location_name  \
# 0                       1.0                      Residence/Home
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       2.0                      Residence/Home
# 3                       1.0                      Residence/Home
# 4                       1.0                      School/College
#
#                         bias_desc victim_types multiple_offense multiple_bias
# 0  Anti-Black or African American   Individual                S             S
# 1                      Anti-White   Individual                M             S
# 2                      Anti-White   Individual                M             S
# 3                      Anti-White   Individual                S             S
# 4  Anti-Black or African American   Individual                S             S

# %%
#indexing df by year
crime_data_df = crime_data_df.set_index('data_year')
crime_data_df.head()
# Out:
#            incident_id    pug_agency_name agency_type_name state_abbr  \
# data_year
# 1991                43         Pine Bluff             City         AR
# 1991                44         Pine Bluff             City         AR
# 1991                45  North Little Rock             City         AR
# 1991                46  North Little Rock             City         AR
# 1991                47             Sevier           County         AR
#
#           state_name       division_name region_name  \
# data_year
# 1991        Arkansas  West South Central       South
# 1991        Arkansas  West South Central       South
# 1991        Arkansas  West South Central       South
# 1991        Arkansas  West South Central       South
# 1991        Arkansas  West South Central       South
#
#                        offender_race offender_ethnicity  victim_count  \
# data_year
# 1991       Black or African American      Not Specified             1
# 1991       Black or African American      Not Specified             2
# 1991       Black or African American      Not Specified             2
# 1991       Black or African American      Not Specified             1
# 1991                           White      Not Specified             1
#
#                                                 offense_name  \
# data_year
# 1991                                      Aggravated Assault
# 1991       Aggravated Assault;Destruction/Damage/Vandalis...
# 1991       Aggravated Assault;Murder and Nonnegligent Man...
# 1991                                            Intimidation
# 1991                                            Intimidation
#
#            total_individual_victims                       location_name  \
# data_year
# 1991                            1.0                      Residence/Home
# 1991                            1.0  Highway/Road/Alley/Street/Sidewalk
# 1991                            2.0                      Residence/Home
# 1991                            1.0                      Residence/Home
# 1991                            1.0                      School/College
#
#                                 bias_desc victim_types multiple_offense  \
# data_year
# 1991       Anti-Black or African American   Individual                S
# 1991                           Anti-White   Individual                M
# 1991                           Anti-White   Individual                M
# 1991                           Anti-White   Individual                S
# 1991       Anti-Black or African American   Individual                S
#
#           multiple_bias
# data_year
# 1991                  S
# 1991                  S
# 1991                  S
# 1991                  S
# 1991                  S

# %%
#creating csv file for ethnicity data
ethnicity_types_df = pd.DataFrame(crime_data_df['offender_ethnicity'].unique(), columns=['ethnicity_type'])
ethnicity_types_df.index.name = 'ethnicity_type_id'

print(f"Max column size - ethnicity_type: {ethnicity_types_df['ethnicity_type'].map(lambda x: len(x)).max()}")

ethnicity_types_df
# Out:
# Max column size - ethnicity_type: 22
#                            ethnicity_type
# ethnicity_type_id
# 0                           Not Specified
# 1                                 Unknown
# 2                  Not Hispanic or Latino
# 3                      Hispanic or Latino
# 4                                Multiple

# %%
#exporting ethnicity dataframe as a csv for upload
ethnicity_types_df.to_csv('resources/ethnicity_types.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %%
#creating csv for offenses data
#splitting multiple offenses
filtered_df = crime_data_df[crime_data_df["multiple_offense"]=="M"]
filtered_df["offense_name"] =filtered_df["offense_name"].str.split(';')
explode_df = filtered_df.explode("offense_name", ignore_index=True)
explode_df.head(20)
# Out:
# C:\Users\a2pha\AppData\Local\Temp\ipykernel_8644\1621890545.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["offense_name"] =filtered_df["offense_name"].str.split(';')
#     incident_id    pug_agency_name agency_type_name state_abbr state_name  \
# 0            44         Pine Bluff             City         AR   Arkansas
# 1            44         Pine Bluff             City         AR   Arkansas
# 2            45  North Little Rock             City         AR   Arkansas
# 3            45  North Little Rock             City         AR   Arkansas
# 4            23            Phoenix             City         AZ    Arizona
# 5            23            Phoenix             City         AZ    Arizona
# 6            31            Phoenix             City         AZ    Arizona
# 7            31            Phoenix             City         AZ    Arizona
# 8            55             Denver             City         CO   Colorado
# 9            55             Denver             City         CO   Colorado
# 10           90           Arapahoe           County         CO   Colorado
# 11           90           Arapahoe           County         CO   Colorado
# 12          100   Colorado Springs             City         CO   Colorado
# 13          100   Colorado Springs             City         CO   Colorado
# 14          100   Colorado Springs             City         CO   Colorado
# 15          112           Trinidad             City         CO   Colorado
# 16          112           Trinidad             City         CO   Colorado
# 17          112           Trinidad             City         CO   Colorado
# 18         2757             Aurora             City         CO   Colorado
# 19         2757             Aurora             City         CO   Colorado
#
#          division_name region_name              offender_race  \
# 0   West South Central       South  Black or African American
# 1   West South Central       South  Black or African American
# 2   West South Central       South  Black or African American
# 3   West South Central       South  Black or African American
# 4             Mountain        West                      White
# 5             Mountain        West                      White
# 6             Mountain        West                      White
# 7             Mountain        West                      White
# 8             Mountain        West                      White
# 9             Mountain        West                      White
# 10            Mountain        West                      White
# 11            Mountain        West                      White
# 12            Mountain        West                      White
# 13            Mountain        West                      White
# 14            Mountain        West                      White
# 15            Mountain        West                    Unknown
# 16            Mountain        West                    Unknown
# 17            Mountain        West                    Unknown
# 18            Mountain        West  Black or African American
# 19            Mountain        West  Black or African American
#
#    offender_ethnicity  victim_count                              offense_name  \
# 0       Not Specified             2                        Aggravated Assault
# 1       Not Specified             2  Destruction/Damage/Vandalism of Property
# 2       Not Specified             2                        Aggravated Assault
# 3       Not Specified             2      Murder and Nonnegligent Manslaughter
# 4       Not Specified             3  Destruction/Damage/Vandalism of Property
# 5       Not Specified             3                              Intimidation
# 6       Not Specified             2                        Aggravated Assault
# 7       Not Specified             2                              Intimidation
# 8       Not Specified             2                        Aggravated Assault
# 9       Not Specified             2                              Intimidation
# 10      Not Specified             3                              Intimidation
# 11      Not Specified             3                            Simple Assault
# 12      Not Specified             6  Destruction/Damage/Vandalism of Property
# 13      Not Specified             6                              Intimidation
# 14      Not Specified             6                            Simple Assault
# 15      Not Specified             3              Burglary/Breaking & Entering
# 16      Not Specified             3  Destruction/Damage/Vandalism of Property
# 17      Not Specified             3                             Not Specified
# 18      Not Specified             2                        Aggravated Assault
# 19      Not Specified             2                             Not Specified
#
#     total_individual_victims                       location_name  \
# 0                        1.0  Highway/Road/Alley/Street/Sidewalk
# 1                        1.0  Highway/Road/Alley/Street/Sidewalk
# 2                        2.0                      Residence/Home
# 3                        2.0                      Residence/Home
# 4                        2.0  Highway/Road/Alley/Street/Sidewalk
# 5                        2.0  Highway/Road/Alley/Street/Sidewalk
# 6                        2.0                 Grocery/Supermarket
# 7                        2.0                 Grocery/Supermarket
# 8                        1.0  Highway/Road/Alley/Street/Sidewalk
# 9                        1.0  Highway/Road/Alley/Street/Sidewalk
# 10                       3.0                 Service/Gas Station
# 11                       3.0                 Service/Gas Station
# 12                       2.0             Parking/Drop Lot/Garage
# 13                       2.0             Parking/Drop Lot/Garage
# 14                       2.0             Parking/Drop Lot/Garage
# 15                       0.0      Church/Synagogue/Temple/Mosque
# 16                       0.0      Church/Synagogue/Temple/Mosque
# 17                       0.0      Church/Synagogue/Temple/Mosque
# 18                       1.0           Department/Discount Store
# 19                       1.0           Department/Discount Store
#
#                          bias_desc            victim_types multiple_offense  \
# 0                       Anti-White              Individual                M
# 1                       Anti-White              Individual                M
# 2                       Anti-White              Individual                M
# 3                       Anti-White              Individual                M
# 4   Anti-Black or African American              Individual                M
# 5   Anti-Black or African American              Individual                M
# 6   Anti-Black or African American              Individual                M
# 7   Anti-Black or African American              Individual                M
# 8   Anti-Black or African American              Individual                M
# 9   Anti-Black or African American              Individual                M
# 10         Anti-Hispanic or Latino              Individual                M
# 11         Anti-Hispanic or Latino              Individual                M
# 12  Anti-Black or African American              Individual                M
# 13  Anti-Black or African American              Individual                M
# 14  Anti-Black or African American              Individual                M
# 15                   Anti-Catholic  Religious Organization                M
# 16                   Anti-Catholic  Religious Organization                M
# 17                   Anti-Catholic  Religious Organization                M
# 18                      Anti-White     Business;Individual                M
# 19                      Anti-White     Business;Individual                M
#
#    multiple_bias
# 0              S
# 1              S
# 2              S
# 3              S
# 4              S
# 5              S
# 6              S
# 7              S
# 8              S
# 9              S
# 10             S
# 11             S
# 12             S
# 13             S
# 14             S
# 15             S
# 16             S
# 17             S
# 18             S
# 19             S

# %%
#creating dataframe of offense types
offense_types_df = pd.DataFrame(explode_df['offense_name'].unique(), columns=['offense_type'])
offense_types_df.index.name = 'offense_type_id'

print(f"Max column size - offense_type: {offense_types_df['offense_type'].map(lambda x: len(x)).max()}")

offense_types_df
# Out:
# Max column size - offense_type: 43
#                                                 offense_type
# offense_type_id
# 0                                         Aggravated Assault
# 1                   Destruction/Damage/Vandalism of Property
# 2                       Murder and Nonnegligent Manslaughter
# 3                                               Intimidation
# 4                                             Simple Assault
# 5                               Burglary/Breaking & Entering
# 6                                              Not Specified
# 7                                                      Arson
# 8                                                    Robbery
# 9                                                       Rape
# 10                                       Motor Vehicle Theft
# 11                                         All Other Larceny
# 12                                     Weapon Law Violations
# 13                                  Theft From Motor Vehicle
# 14                                               Shoplifting
# 15                                      Kidnapping/Abduction
# 16               Theft of Motor Vehicle Parts or Accessories
# 17                                                    Sodomy
# 18                                  Stolen Property Offenses
# 19                                 Drug Equipment Violations
# 20                                  Drug/Narcotic Violations
# 21                                       Theft From Building
# 22                                    Counterfeiting/Forgery
# 23                                             Impersonation
# 24                                       Extortion/Blackmail
# 25                                                  Fondling
# 26                   False Pretenses/Swindle/Confidence Game
# 27                              Pornography/Obscene Material
# 28                                              Embezzlement
# 29                             Sexual Assault With An Object
# 30                Credit Card/Automated Teller Machine Fraud
# 31                                           Purse-snatching
# 32                                              Prostitution
# 33                                            Pocket-picking
# 34                                            Statutory Rape
# 35                                                   Bribery
# 36                                            Identity Theft
# 37                                                Wire Fraud
# 38                    Human Trafficking, Commercial Sex Acts
# 39                                            Animal Cruelty
# 40                                 Hacking/Computer Invasion

# %%
#exporting offenses dataframe as a csv for upload
offense_types_df.to_csv('resources/offense_types.csv')

# Confirm that export completed
print('Dataframe exported to csv')
# Out:
# Dataframe exported to csv

# %%
#creating dataframe for incident id numbers
incident_id_df = pd.DataFrame(crime_data_df['incident_id'].unique(), columns=['incident_id'])
incident_id_df.index.name = 'incident_id'

print(f"Max column size - incident_id: {incident_id_df['incident_id'].max()}")

incident_id_df
# Out:
# Max column size - incident_id: 1450227
#              incident_id
# incident_id
# 0                     43
# 1                     44
# 2                     45
# 3                     46
# 4                     47
# ...                  ...
# 226323           1445214
# 226324           1445630
# 226325           1448544
# 226326           1448545
# 226327           1448546
#
# [226328 rows x 1 columns]
