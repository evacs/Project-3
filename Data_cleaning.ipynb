# %% [markdown]
# # Extract, Transform and Load data

# %%
# Import dependencies
import pandas as pd
import numpy as np

# %% [markdown]
# ### Extract the hate crime data

# %%
# Read the data into a Pandas DataFrame
hcrime_df = pd.read_excel('C:/Users/tnord/Downloads/hate_crimes_from_FBI.xlsx')
hcrime_df.head()
# Out:
#    incident_id  data_year        ori    pug_agency_name pub_agency_unit  \
# 0           43       1991  AR0350100         Pine Bluff             NaN
# 1           44       1991  AR0350100         Pine Bluff             NaN
# 2           45       1991  AR0600300  North Little Rock             NaN
# 3           46       1991  AR0600300  North Little Rock             NaN
# 4           47       1991  AR0670000             Sevier             NaN
#
#   agency_type_name state_abbr state_name       division_name region_name  ...  \
# 0             City         AR   Arkansas  West South Central       South  ...
# 1             City         AR   Arkansas  West South Central       South  ...
# 2             City         AR   Arkansas  West South Central       South  ...
# 3             City         AR   Arkansas  West South Central       South  ...
# 4           County         AR   Arkansas  West South Central       South  ...
#
#                offender_race offender_ethnicity victim_count  \
# 0  Black or African American      Not Specified            1
# 1  Black or African American      Not Specified            2
# 2  Black or African American      Not Specified            2
# 3  Black or African American      Not Specified            1
# 4                      White      Not Specified            1
#
#                                         offense_name  \
# 0                                 Aggravated Assault
# 1  Aggravated Assault;Destruction/Damage/Vandalis...
# 2  Aggravated Assault;Murder and Nonnegligent Man...
# 3                                       Intimidation
# 4                                       Intimidation
#
#    total_individual_victims                       location_name  \
# 0                       1.0                      Residence/Home
# 1                       1.0  Highway/Road/Alley/Street/Sidewalk
# 2                       2.0                      Residence/Home
# 3                       1.0                      Residence/Home
# 4                       1.0                      School/College
#
#                         bias_desc  victim_types multiple_offense multiple_bias
# 0  Anti-Black or African American    Individual                S             S
# 1                      Anti-White    Individual                M             S
# 2                      Anti-White    Individual                M             S
# 3                      Anti-White    Individual                S             S
# 4  Anti-Black or African American    Individual                S             S
#
# [5 rows x 28 columns]

# %%
hcrime_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226328 entries, 0 to 226327
# Data columns (total 28 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   incident_id                   226328 non-null  int64
#  1   data_year                     226328 non-null  int64
#  2   ori                           226328 non-null  object
#  3   pug_agency_name               226328 non-null  object
#  4   pub_agency_unit               6563 non-null    object
#  5   agency_type_name              226328 non-null  object
#  6   state_abbr                    226328 non-null  object
#  7   state_name                    226328 non-null  object
#  8   division_name                 226328 non-null  object
#  9   region_name                   226328 non-null  object
#  10  population_group_code         225924 non-null  object
#  11  population_group_description  225924 non-null  object
#  12  incident_date                 226328 non-null  datetime64[ns]
#  13  adult_victim_count            58203 non-null   float64
#  14  juvenile_victim_count         56331 non-null   float64
#  15  total_offender_count          226328 non-null  int64
#  16  adult_offender_count          53462 non-null   float64
#  17  juvenile_offender_count       53455 non-null   float64
#  18  offender_race                 226328 non-null  object
#  19  offender_ethnicity            226328 non-null  object
#  20  victim_count                  226328 non-null  int64
#  21  offense_name                  226328 non-null  object
#  22  total_individual_victims      222849 non-null  float64
#  23  location_name                 226328 non-null  object
#  24  bias_desc                     226328 non-null  object
#  25  victim_types                  226328 non-null  object
#  26  multiple_offense              226328 non-null  object
#  27  multiple_bias                 226328 non-null  object
# dtypes: datetime64[ns](1), float64(5), int64(4), object(18)
# memory usage: 48.3+ MB

# %%
#Dropping columns that will not be used
drop_col = ["pub_agency_unit","adult_victim_count","juvenile_victim_count","adult_offender_count","juvenile_offender_count"]
hcrime = hcrime_df.drop(columns= drop_col)
hcrime.head()
# Out:
#    incident_id  data_year        ori    pug_agency_name agency_type_name  \
# 0           43       1991  AR0350100         Pine Bluff             City
# 1           44       1991  AR0350100         Pine Bluff             City
# 2           45       1991  AR0600300  North Little Rock             City
# 3           46       1991  AR0600300  North Little Rock             City
# 4           47       1991  AR0670000             Sevier           County
#
#   state_abbr state_name       division_name region_name population_group_code  \
# 0         AR   Arkansas  West South Central       South                     3
# 1         AR   Arkansas  West South Central       South                     3
# 2         AR   Arkansas  West South Central       South                     3
# 3         AR   Arkansas  West South Central       South                     3
# 4         AR   Arkansas  West South Central       South                    8D
#
#    ...              offender_race offender_ethnicity  victim_count  \
# 0  ...  Black or African American      Not Specified             1
# 1  ...  Black or African American      Not Specified             2
# 2  ...  Black or African American      Not Specified             2
# 3  ...  Black or African American      Not Specified             1
# 4  ...                      White      Not Specified             1
#
#                                         offense_name total_individual_victims  \
# 0                                 Aggravated Assault                      1.0
# 1  Aggravated Assault;Destruction/Damage/Vandalis...                      1.0
# 2  Aggravated Assault;Murder and Nonnegligent Man...                      2.0
# 3                                       Intimidation                      1.0
# 4                                       Intimidation                      1.0
#
#                         location_name                       bias_desc  \
# 0                      Residence/Home  Anti-Black or African American
# 1  Highway/Road/Alley/Street/Sidewalk                      Anti-White
# 2                      Residence/Home                      Anti-White
# 3                      Residence/Home                      Anti-White
# 4                      School/College  Anti-Black or African American
#
#    victim_types multiple_offense multiple_bias
# 0    Individual                S             S
# 1    Individual                M             S
# 2    Individual                M             S
# 3    Individual                S             S
# 4    Individual                S             S
#
# [5 rows x 23 columns]

# %%
hcrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 226328 entries, 0 to 226327
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   incident_id                   226328 non-null  int64
#  1   data_year                     226328 non-null  int64
#  2   ori                           226328 non-null  object
#  3   pug_agency_name               226328 non-null  object
#  4   agency_type_name              226328 non-null  object
#  5   state_abbr                    226328 non-null  object
#  6   state_name                    226328 non-null  object
#  7   division_name                 226328 non-null  object
#  8   region_name                   226328 non-null  object
#  9   population_group_code         225924 non-null  object
#  10  population_group_description  225924 non-null  object
#  11  incident_date                 226328 non-null  datetime64[ns]
#  12  total_offender_count          226328 non-null  int64
#  13  offender_race                 226328 non-null  object
#  14  offender_ethnicity            226328 non-null  object
#  15  victim_count                  226328 non-null  int64
#  16  offense_name                  226328 non-null  object
#  17  total_individual_victims      222849 non-null  float64
#  18  location_name                 226328 non-null  object
#  19  bias_desc                     226328 non-null  object
#  20  victim_types                  226328 non-null  object
#  21  multiple_offense              226328 non-null  object
#  22  multiple_bias                 226328 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(17)
# memory usage: 39.7+ MB

# %%
filtered_df = hcrime[hcrime["multiple_bias"]=="M"]
filtered_df["bias_desc"] =filtered_df["bias_desc"].str.split(';')
explode_df = filtered_df.explode("bias_desc", ignore_index=True)
explode_df.head(20)
# Out:
# C:\Users\tnord\AppData\Local\Temp\ipykernel_13876\2254811834.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df["bias_desc"] =filtered_df["bias_desc"].str.split(';')
#     incident_id  data_year        ori pug_agency_name agency_type_name  \
# 0           662       1991  MA0091100       Cambridge             City
# 1           662       1991  MA0091100       Cambridge             City
# 2           689       1991  MA0130100          Boston             City
# 3           689       1991  MA0130100          Boston             City
# 4           696       1991  MA0130100          Boston             City
# 5           696       1991  MA0130100          Boston             City
# 6          3259       1991  MA0130100          Boston             City
# 7          3259       1991  MA0130100          Boston             City
# 8          3272       1991  MA0130100          Boston             City
# 9          3272       1991  MA0130100          Boston             City
# 10          891       1991  MOSPD0000       St. Louis             City
# 11          891       1991  MOSPD0000       St. Louis             City
# 12          904       1991  MOSPD0000       St. Louis             City
# 13          904       1991  MOSPD0000       St. Louis             City
# 14         2539       1991  TXDPD0000          Dallas             City
# 15         2539       1991  TXDPD0000          Dallas             City
# 16         6243       1992  MOSPD0000       St. Louis             City
# 17         6243       1992  MOSPD0000       St. Louis             City
# 18        11674       1993  CO0030000        Arapahoe           County
# 19        11674       1993  CO0030000        Arapahoe           County
#
#    state_abbr     state_name       division_name region_name  \
# 0          MA  Massachusetts         New England   Northeast
# 1          MA  Massachusetts         New England   Northeast
# 2          MA  Massachusetts         New England   Northeast
# 3          MA  Massachusetts         New England   Northeast
# 4          MA  Massachusetts         New England   Northeast
# 5          MA  Massachusetts         New England   Northeast
# 6          MA  Massachusetts         New England   Northeast
# 7          MA  Massachusetts         New England   Northeast
# 8          MA  Massachusetts         New England   Northeast
# 9          MA  Massachusetts         New England   Northeast
# 10         MO       Missouri  West North Central     Midwest
# 11         MO       Missouri  West North Central     Midwest
# 12         MO       Missouri  West North Central     Midwest
# 13         MO       Missouri  West North Central     Midwest
# 14         TX          Texas  West South Central       South
# 15         TX          Texas  West South Central       South
# 16         MO       Missouri  West North Central     Midwest
# 17         MO       Missouri  West North Central     Midwest
# 18         CO       Colorado            Mountain        West
# 19         CO       Colorado            Mountain        West
#
#    population_group_code  ...              offender_race offender_ethnicity  \
# 0                      3  ...                      White      Not Specified
# 1                      3  ...                      White      Not Specified
# 2                     1B  ...                      White      Not Specified
# 3                     1B  ...                      White      Not Specified
# 4                     1B  ...                      White      Not Specified
# 5                     1B  ...                      White      Not Specified
# 6                     1B  ...                      White      Not Specified
# 7                     1B  ...                      White      Not Specified
# 8                     1B  ...                      Asian      Not Specified
# 9                     1B  ...                      Asian      Not Specified
# 10                    1C  ...                   Multiple      Not Specified
# 11                    1C  ...                   Multiple      Not Specified
# 12                    1C  ...                   Multiple      Not Specified
# 13                    1C  ...                   Multiple      Not Specified
# 14                    1A  ...                      White      Not Specified
# 15                    1A  ...                      White      Not Specified
# 16                    1C  ...                   Multiple      Not Specified
# 17                    1C  ...                   Multiple      Not Specified
# 18                    9A  ...  Black or African American      Not Specified
# 19                    9A  ...  Black or African American      Not Specified
#
#     victim_count                                       offense_name  \
# 0              2                             Robbery;Simple Assault
# 1              2                             Robbery;Simple Assault
# 2              2                               Intimidation;Robbery
# 3              2                               Intimidation;Robbery
# 4              2   Destruction/Damage/Vandalism of Property;Robbery
# 5              2   Destruction/Damage/Vandalism of Property;Robbery
# 6              2  Aggravated Assault;Destruction/Damage/Vandalis...
# 7              2  Aggravated Assault;Destruction/Damage/Vandalis...
# 8              2                        Intimidation;Simple Assault
# 9              2                        Intimidation;Simple Assault
# 10             2                        Intimidation;Simple Assault
# 11             2                        Intimidation;Simple Assault
# 12            15  Aggravated Assault;Intimidation;Murder and Non...
# 13            15  Aggravated Assault;Intimidation;Murder and Non...
# 14             2                        Intimidation;Simple Assault
# 15             2                        Intimidation;Simple Assault
# 16             3                  Aggravated Assault;Simple Assault
# 17             3                  Aggravated Assault;Simple Assault
# 18             4                        Intimidation;Simple Assault
# 19             4                        Intimidation;Simple Assault
#
#    total_individual_victims                       location_name  \
# 0                       1.0                       Other/Unknown
# 1                       1.0                       Other/Unknown
# 2                       1.0                       Other/Unknown
# 3                       1.0                       Other/Unknown
# 4                       1.0                       Other/Unknown
# 5                       1.0                       Other/Unknown
# 6                       1.0                       Other/Unknown
# 7                       1.0                       Other/Unknown
# 8                       1.0                       Other/Unknown
# 9                       1.0                       Other/Unknown
# 10                      2.0                 Service/Gas Station
# 11                      2.0                 Service/Gas Station
# 12                     15.0             Parking/Drop Lot/Garage
# 13                     15.0             Parking/Drop Lot/Garage
# 14                      2.0                          Restaurant
# 15                      2.0                          Restaurant
# 16                      3.0  Highway/Road/Alley/Street/Sidewalk
# 17                      3.0  Highway/Road/Alley/Street/Sidewalk
# 18                      4.0                      Residence/Home
# 19                      4.0                      Residence/Home
#
#                          bias_desc  victim_types multiple_offense  \
# 0                  Anti-Gay (Male)    Individual                M
# 1                       Anti-White    Individual                M
# 2   Anti-Black or African American    Individual                M
# 3                      Anti-Jewish    Individual                M
# 4   Anti-Black or African American    Individual                M
# 5            Anti-Lesbian (Female)    Individual                M
# 6                  Anti-Gay (Male)    Individual                M
# 7                       Anti-White    Individual                M
# 8   Anti-Black or African American    Individual                M
# 9                  Anti-Gay (Male)    Individual                M
# 10  Anti-Black or African American    Individual                M
# 11                      Anti-White    Individual                M
# 12  Anti-Black or African American    Individual                M
# 13                      Anti-White    Individual                M
# 14                 Anti-Gay (Male)    Individual                M
# 15                     Anti-Jewish    Individual                M
# 16  Anti-Black or African American    Individual                M
# 17                      Anti-White    Individual                M
# 18  Anti-Black or African American    Individual                M
# 19                      Anti-White    Individual                M
#
#    multiple_bias
# 0              M
# 1              M
# 2              M
# 3              M
# 4              M
# 5              M
# 6              M
# 7              M
# 8              M
# 9              M
# 10             M
# 11             M
# 12             M
# 13             M
# 14             M
# 15             M
# 16             M
# 17             M
# 18             M
# 19             M
#
# [20 rows x 23 columns]

# %%
explode_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   incident_id                   2580 non-null   int64
#  1   data_year                     2580 non-null   int64
#  2   ori                           2580 non-null   object
#  3   pug_agency_name               2580 non-null   object
#  4   agency_type_name              2580 non-null   object
#  5   state_abbr                    2580 non-null   object
#  6   state_name                    2580 non-null   object
#  7   division_name                 2580 non-null   object
#  8   region_name                   2580 non-null   object
#  9   population_group_code         2527 non-null   object
#  10  population_group_description  2527 non-null   object
#  11  incident_date                 2580 non-null   datetime64[ns]
#  12  total_offender_count          2580 non-null   int64
#  13  offender_race                 2580 non-null   object
#  14  offender_ethnicity            2580 non-null   object
#  15  victim_count                  2580 non-null   int64
#  16  offense_name                  2580 non-null   object
#  17  total_individual_victims      2183 non-null   float64
#  18  location_name                 2580 non-null   object
#  19  bias_desc                     2580 non-null   object
#  20  victim_types                  2580 non-null   object
#  21  multiple_offense              2580 non-null   object
#  22  multiple_bias                 2580 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(17)
# memory usage: 463.7+ KB

# %%
filtered_df2 = hcrime[hcrime["multiple_bias"]=="S"]
final_df = filtered_df2.merge(explode_df,how ='outer')

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 227709 entries, 0 to 227708
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   incident_id                   227709 non-null  int64
#  1   data_year                     227709 non-null  int64
#  2   ori                           227709 non-null  object
#  3   pug_agency_name               227709 non-null  object
#  4   agency_type_name              227709 non-null  object
#  5   state_abbr                    227709 non-null  object
#  6   state_name                    227709 non-null  object
#  7   division_name                 227709 non-null  object
#  8   region_name                   227709 non-null  object
#  9   population_group_code         227278 non-null  object
#  10  population_group_description  227278 non-null  object
#  11  incident_date                 227709 non-null  datetime64[ns]
#  12  total_offender_count          227709 non-null  int64
#  13  offender_race                 227709 non-null  object
#  14  offender_ethnicity            227709 non-null  object
#  15  victim_count                  227709 non-null  int64
#  16  offense_name                  227709 non-null  object
#  17  total_individual_victims      224008 non-null  float64
#  18  location_name                 227709 non-null  object
#  19  bias_desc                     227709 non-null  object
#  20  victim_types                  227709 non-null  object
#  21  multiple_offense              227709 non-null  object
#  22  multiple_bias                 227709 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(4), object(17)
# memory usage: 41.7+ MB

# %%
# Export the DataFrame as a CSV file. 
final_df.to_csv("resources/hate_crime.csv", index=False)

# %% [markdown]
# ## Creating Categories for Biases

# %%
final_df["bias_desc"].unique()
# Out:
# array(['Anti-Black or African American', 'Anti-White', 'Anti-Jewish',
#        'Anti-Arab', 'Anti-Protestant', 'Anti-Other Religion',
#        'Anti-Islamic (Muslim)', 'Anti-Gay (Male)', 'Anti-Asian',
#        'Anti-Catholic', 'Anti-Multiple Religions, Group',
#        'Anti-Hispanic or Latino', 'Anti-Multiple Races, Group',
#        'Anti-Lesbian (Female)', 'Anti-Other Race/Ethnicity/Ancestry',
#        'Anti-Heterosexual',
#        'Anti-Lesbian, Gay, Bisexual, or Transgender (Mixed Group)',
#        'Anti-American Indian or Alaska Native',
#        'Anti-Atheism/Agnosticism', 'Anti-Bisexual',
#        'Anti-Physical Disability', 'Anti-Mental Disability',
#        'Anti-Gender Non-Conforming', 'Anti-Female', 'Anti-Transgender',
#        'Anti-Native Hawaiian or Other Pacific Islander', 'Anti-Male',
#        "Anti-Jehovah's Witness", 'Anti-Church of Jesus Christ',
#        'Anti-Buddhist', 'Anti-Sikh', 'Anti-Other Christian', 'Anti-Hindu',
#        'Anti-Eastern Orthodox (Russian, Greek, Other)',
#        "Unknown (offender's motivation not known)"], dtype=object)

# %%
Sexual_orientation = ['Anti-Gay (Male)','Anti-Lesbian (Female)','Anti-Lesbian, Gay, Bisexual, or Transgender (Mixed Group)','Anti-Bisexual','Anti-Heterosexual']
Religion = ['Anti-Jewish','Anti-Arab', 'Anti-Protestant', 'Anti-Other Religion','Anti-Islamic (Muslim)', 'Anti-Catholic', 'Anti-Multiple Religions, Group','Anti-Atheism/Agnosticism','Anti-Buddhist', 'Anti-Sikh', 'Anti-Other Christian', 'Anti-Hindu','Anti-Eastern Orthodox (Russian, Greek, Other)',"Anti-Jehovah's Witness", 'Anti-Church of Jesus Christ']
Race_Ethnicity_Ancestry = ['Anti-Black or African American', 'Anti-White','Anti-Arab','Anti-Asian','Anti-Hispanic or Latino', 'Anti-Multiple Races, Group','Anti-Other Race/Ethnicity/Ancestry','Anti-American Indian or Alaska Native','Anti-Native Hawaiian or Other Pacific Islander']
Gender_identity = ['Anti-Gender Non-Conforming','Anti-Transgender']
Gender = ['Anti-Female','Anti-Male']
Disability = ['Anti-Physical Disability', 'Anti-Mental Disability']

# len(Sexual_orientation)
# len(Religion)
# len(Race_Ethnicity_Ancestry)
# len(Gender_identity)
# len(Gender)
# len(Disability)

# %%
bias = final_df["bias_desc"].unique().tolist()

# %%
data = {'category': "Sexual_orientation", 'bias': Sexual_orientation}
sexual_orientation_df = pd.DataFrame(data, columns = ['category','bias'])
sexual_orientation_df
# Out:
#              category                                               bias
# 0  Sexual_orientation                                    Anti-Gay (Male)
# 1  Sexual_orientation                              Anti-Lesbian (Female)
# 2  Sexual_orientation  Anti-Lesbian, Gay, Bisexual, or Transgender (M...
# 3  Sexual_orientation                                      Anti-Bisexual
# 4  Sexual_orientation                                  Anti-Heterosexual

# %%
data = {'category': "Religion", 'bias': Religion}
Religion_df = pd.DataFrame(data, columns = ['category','bias'])
Religion_df
# Out:
#     category                                           bias
# 0   Religion                                    Anti-Jewish
# 1   Religion                                      Anti-Arab
# 2   Religion                                Anti-Protestant
# 3   Religion                            Anti-Other Religion
# 4   Religion                          Anti-Islamic (Muslim)
# 5   Religion                                  Anti-Catholic
# 6   Religion                 Anti-Multiple Religions, Group
# 7   Religion                       Anti-Atheism/Agnosticism
# 8   Religion                                  Anti-Buddhist
# 9   Religion                                      Anti-Sikh
# 10  Religion                           Anti-Other Christian
# 11  Religion                                     Anti-Hindu
# 12  Religion  Anti-Eastern Orthodox (Russian, Greek, Other)
# 13  Religion                         Anti-Jehovah's Witness
# 14  Religion                    Anti-Church of Jesus Christ

# %%
data = {'category': "Race_Ethnicity_Ancestry", 'bias': Race_Ethnicity_Ancestry}
Race_Ethnicity_Ancestry_df = pd.DataFrame(data, columns = ['category','bias'])
Race_Ethnicity_Ancestry_df
# Out:
#                   category                                            bias
# 0  Race_Ethnicity_Ancestry                  Anti-Black or African American
# 1  Race_Ethnicity_Ancestry                                      Anti-White
# 2  Race_Ethnicity_Ancestry                                       Anti-Arab
# 3  Race_Ethnicity_Ancestry                                      Anti-Asian
# 4  Race_Ethnicity_Ancestry                         Anti-Hispanic or Latino
# 5  Race_Ethnicity_Ancestry                      Anti-Multiple Races, Group
# 6  Race_Ethnicity_Ancestry              Anti-Other Race/Ethnicity/Ancestry
# 7  Race_Ethnicity_Ancestry           Anti-American Indian or Alaska Native
# 8  Race_Ethnicity_Ancestry  Anti-Native Hawaiian or Other Pacific Islander

# %%
data = {'category': "Gender_identity", 'bias': Gender_identity}
Gender_identity_df = pd.DataFrame(data, columns = ['category','bias'])
Gender_identity_df
# Out:
#           category                        bias
# 0  Gender_identity  Anti-Gender Non-Conforming
# 1  Gender_identity            Anti-Transgender

# %%
data = {'category': "Gender", 'bias': Gender}
Gender_df = pd.DataFrame(data, columns = ['category','bias'])
Gender_df
# Out:
#   category         bias
# 0   Gender  Anti-Female
# 1   Gender    Anti-Male

# %%
data = {'category': "Disability", 'bias': Disability}
Disability_df = pd.DataFrame(data, columns = ['category','bias'])
Disability_df
# Out:
#      category                      bias
# 0  Disability  Anti-Physical Disability
# 1  Disability    Anti-Mental Disability

# %%
bias_df = sexual_orientation_df.merge(Religion_df,how ='outer').merge(Race_Ethnicity_Ancestry_df, how ="outer").merge(Gender_identity_df, how ="outer").merge(Gender_df, how ="outer").merge(Disability_df, how ="outer")
# Out:
#            category                      bias
# 30  Gender_identity          Anti-Transgender
# 31           Gender               Anti-Female
# 32           Gender                 Anti-Male
# 33       Disability  Anti-Physical Disability
# 34       Disability    Anti-Mental Disability

# %%
#Saving to csv file
bias_df.to_csv("resources/bias_category.csv", index=False)
